# %%
# Import necessary libraries/modules
import vertica_python
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

import os

# %%
# Set up the Vertica Connection Information
username = os.getenv('VERTICA_USERNAME')
password = os.getenv('VERTICA_PASSWORD')

conn_info = {'host': 'warehouse.analytics.edx.org',
             'port': 5433,
             'user': username,
             'password': password,
             'database': 'warehouse',
             'read_timeout': 600,
             'unicode_error': 'strict',
             'ssl': False
            }

connection = vertica_python.connect(**conn_info)
cur = connection.cursor('dict')

# %%
preprocess_query="""
-- Create Binary Columns for each subject within a course_id
DROP TABLE IF EXISTS tmp_course_subjects;
CREATE LOCAL TEMPORARY TABLE IF NOT EXISTS tmp_course_subjects ON COMMIT PRESERVE ROWS AS
SELECT	
	DISTINCT course_id,
	CASE 
		WHEN subject_title = 'Architecture' THEN 1
		ELSE 0
	END AS Architecture,
	CASE 
		WHEN subject_title = 'Art & Culture' THEN 1
		ELSE 0
	END AS ArtCulture,
	CASE 
		WHEN subject_title = 'Biology & Life Sciences' THEN 1
		ELSE 0
	END AS BiologyLifeSciences,
	CASE 
		WHEN subject_title = 'Business & Management' THEN 1
		ELSE 0
	END AS BusinessManagement,
	CASE 
		WHEN subject_title = 'Chemistry' THEN 1
		ELSE 0
	END AS Chemistry,
	CASE 
		WHEN subject_title = 'Communication' THEN 1
		ELSE 0
	END AS Communication,
	CASE 
		WHEN subject_title = 'Computer Science' THEN 1
		ELSE 0
	END AS ComputerScience,
	CASE 
		WHEN subject_title = 'Data Analysis & Statistics' THEN 1
		ELSE 0
	END AS DataAnalysisStatistics,
	CASE 
		WHEN subject_title = 'Design' THEN 1
		ELSE 0
	END AS Design,
	CASE 
		WHEN subject_title = 'Economics & Finance' THEN 1
		ELSE 0
	END AS EconomicsFinance,
	CASE 
		WHEN subject_title = 'Education & Teacher Training' THEN 1
		ELSE 0
	END AS EducationTeacherTraining,
	CASE 
		WHEN subject_title = 'Electronics' THEN 1
		ELSE 0
	END AS Electronics,
	CASE 
		WHEN subject_title = 'Energy & Earth Sciences' THEN 1
		ELSE 0
	END AS EnergyEarthSciences,
	CASE 
		WHEN subject_title = 'Engineering' THEN 1
		ELSE 0
	END AS Engineering,
	CASE 
		WHEN subject_title = 'Environmental Studies' THEN 1
		ELSE 0
	END AS EnvironmentalStudies,
	CASE 
		WHEN subject_title = 'Ethics' THEN 1
		ELSE 0
	END AS Ethics,
	CASE 
		WHEN subject_title = 'Food & Nutrition' THEN 1
		ELSE 0
	END AS FoodNutrition,
	CASE 
		WHEN subject_title = 'Health & Safety' THEN 1
		ELSE 0
	END AS HealthSafety,
	CASE 
		WHEN subject_title = 'History' THEN 1
		ELSE 0
	END AS History,
	CASE 
		WHEN subject_title = 'Humanities' THEN 1
		ELSE 0
	END AS Humanities,
		CASE 
		WHEN subject_title = 'Language' THEN 1
		ELSE 0
	END AS Languag,
		CASE 
		WHEN subject_title = 'Law' THEN 1
		ELSE 0
	END AS Law,
		CASE 
		WHEN subject_title = 'Literature' THEN 1
		ELSE 0
	END AS Literature,
		CASE 
		WHEN subject_title = 'Math' THEN 1
		ELSE 0
	END AS Math,
		CASE 
		WHEN subject_title = 'Medicine' THEN 1
		ELSE 0
	END AS Medicine,
		CASE 
		WHEN subject_title = 'Music' THEN 1
		ELSE 0
	END AS Music,
		CASE 
		WHEN subject_title = 'Philosophy & Ethics' THEN 1
		ELSE 0
	END AS PhilosophyEthics,
		CASE 
		WHEN subject_title = 'Physics' THEN 1
		ELSE 0
	END AS Physics,
		CASE 
		WHEN subject_title = 'Science' THEN 1
		ELSE 0
	END AS Science,
		CASE 
		WHEN subject_title = 'Social Sciences' THEN 1
		ELSE 0
	END AS SocialSciences
FROM
	production.d_course_subjects;
	
--Roll up the subjects at the course_id level
DROP TABLE IF EXISTS ed_services.course_subjects;	
CREATE TABLE IF NOT EXISTS ed_services.course_subjects AS
SELECT
	course_id,
	SUM(Architecture) AS Architecture,
	SUM(ArtCulture) AS ArtCulture,
	SUM(BiologyLifeSciences) AS BiologyLifeSciences,
	SUM(BusinessManagement) AS BusinessManagement,
	SUM(Chemistry) AS Chemistry,
	SUM(Communication) AS Communication,
	SUM(ComputerScience) AS ComputerScience,
	SUM(DataAnalysisStatistics) AS DataAnalysisStatistics,
	SUM(Design) AS Design,
	SUM(EconomicsFinance) AS EconomicsFinance,
	SUM(EducationTeacherTraining) AS EducationTeacherTraining,
	SUM(Electronics) AS Electronics,
	SUM(EnergyEarthSciences) AS EnergyEarthSciences,
	SUM(Engineering) AS Engineering,
	SUM(EnvironmentalStudies) AS EnvironmentalStudies,
	SUM(Ethics) AS Ethics,
	SUM(FoodNutrition) AS FoodNutrition,
	SUM(HealthSafety) AS HealthSafety,
	SUM(History) AS History,
	SUM(Humanities) AS Humanities,
	SUM(Languag) AS Languag,
	SUM(Law) AS Law,
	SUM(Literature) AS Literature,
	SUM(Math) AS Math,
	SUM(Medicine) AS Medicine,
	SUM(Music) AS Music,
	SUM(PhilosophyEthics) AS PhilosophyEthics,
	SUM(Physics) AS Physics,
	SUM(Science) AS Science,
	SUM(SocialSciences) AS SocialSciences,
	COUNT(*) AS cnt_subjects
FROM
	tmp_course_subjects
GROUP BY
	course_id;
    
--Create Binary columns for programs 
DROP TABLE IF EXISTS tmp_course_program;	
CREATE LOCAL TEMPORARY TABLE IF NOT EXISTS tmp_course_program ON COMMIT PRESERVE ROWS AS
SELECT
	course_id,
	CASE
		WHEN program_type = 'XSeries' THEN 1
		ELSE 0
	END AS XSeries,
	CASE
		WHEN program_type = 'Professional Certificate' THEN 1
		ELSE 0
	END AS ProfessionalCertificate,
	CASE
		WHEN program_type = 'MicroMasters' THEN 1
		ELSE 0
	END AS MicroMasters
FROM
	production.d_program_course;

--Sum up the programs columns and add column for non program courses
DROP TABLE IF EXISTS course_program;
CREATE LOCAL TEMPORARY TABLE IF NOT EXISTS course_program ON COMMIT PRESERVE ROWS AS
SELECT
	course_id,
	SUM(XSeries) AS XSeries,
	SUM(ProfessionalCertificate) AS ProfessionalCertificate,
	SUM(MicroMasters) AS MicroMasters
FROM
	tmp_course_program
GROUP BY
	course_id;  
	
--Roll up into a program summary table	
DROP TABLE IF EXISTS ed_services.course_program;
CREATE TABLE IF NOT EXISTS ed_services.course_program AS
SELECT
	a.course_id,
	ISNULL(XSeries, 0) AS XSeries,
	ISNULL(ProfessionalCertificate, 0) AS ProfessionalCertificate,
	ISNULL(MicroMasters, 0) AS MicroMasters,
	CASE
		WHEN XSeries IS NULL THEN 1
		ELSE 0
	END AS NonProgram
FROM
	business_intelligence.course_master a
LEFT JOIN
	course_program b
ON
	a.course_id = b.course_id;

--Create binary column for course track
DROP TABLE IF EXISTS tmp_course_track;	
CREATE LOCAL TEMPORARY TABLE IF NOT EXISTS tmp_course_track ON COMMIT PRESERVE ROWS AS	
SELECT
	course_id,
	CASE
		WHEN course_seat_type IN ('honor', 'audit') THEN 1
		ELSE 0
	END AS audit_track,
	CASE
		WHEN course_seat_type = 'verified' THEN 1
		ELSE 0
	END AS verified_track,
	CASE
		WHEN course_seat_type IN ('no-id-professional', 'professional') THEN 1
		ELSE 0
	END AS professional_track,
	CASE
		WHEN course_seat_type = 'credit' THEN 1
		ELSE 0
	END AS credit_track
FROM
	production.d_course_seat;
	
--Roll up of course tracks per course_id	
DROP TABLE IF EXISTS ed_services.course_track;
CREATE TABLE IF NOT EXISTS ed_services.course_track AS
SELECT
	course_id,
	SUM(audit_track) AS audit_track,
	SUM(verified_track) AS verified_track,
	SUM(professional_track) AS professional_track,
	SUM(credit_track) AS credit_track,
	COUNT(*) AS cnt_available_tracks
FROM
	tmp_course_track
GROUP BY
	course_id;
    
--Partner Rankings    
DROP TABLE IF EXISTS ed_services.partner_rankings;	
CREATE TABLE IF NOT EXISTS ed_services.partner_rankings AS
SELECT
	org_id,
	course_run_count,
	course_count,
	sum_partner_enrolls,
	sum_partner_vtr,
	sum_partner_bookings,
	ISNULL(sum_partner_enrolls/course_run_count, 0) AS enrollments_per_course_run,
	ISNULL(sum_partner_bookings/course_run_count, 0) AS bookings_per_course_run,
	ROW_NUMBER() OVER (ORDER BY sum_partner_enrolls DESC) AS enrollment_rank,
	ROW_NUMBER() OVER (ORDER BY ISNULL(sum_partner_bookings,0) DESC) AS bookings_rank,
	ROW_NUMBER() OVER (ORDER BY ISNULL(sum_partner_vtr, 0) DESC) AS vtr_rank,
	ROW_NUMBER() OVER (ORDER BY ISNULL(sum_partner_enrolls/course_run_count, 0) DESC) AS enrolls_per_course_rank,
	ROW_NUMBER() OVER (ORDER BY ISNULL(sum_partner_bookings/course_run_count, 0) DESC) AS bookings_per_course_rank
FROM
	business_intelligence.partner_stats_summary
WHERE
	org_id IS NOT NULL;    
"""

# Execute the Query from above
cur.execute(preprocess_query)

# %%
query="""
SELECT
	a.course_id,
	Architecture,
	ArtCulture,
	BiologyLifeSciences,
	BusinessManagement,
	Chemistry,
	Communication,
	ComputerScience,
	DataAnalysisStatistics,
	Design,
	EconomicsFinance,
	EducationTeacherTraining,
	Electronics,
	EnergyEarthSciences,
	Engineering,
	EnvironmentalStudies,
	Ethics,
	FoodNutrition,
	HealthSafety,
	History,
	Humanities,
	Languag,
	Law,
	Literature,
	Math,
	Medicine,
	Music,
	PhilosophyEthics,
	Physics,
	Science,
	SocialSciences,
	cnt_subjects,
	is_WL,
	level_type,
	pacing_type,
	course_partner,
	CASE
		WHEN course_partner IN ('MITx', 'HarvardX', 'BerkeleyX', 'UTArlingtonX', 'UTAustinX', 'UTHealthSPHx', 'UTPermianBasin', 'UTSanAntonioX', 'UTMBx', 'UQx', 'DelftX') THEN 1 ELSE 0
	END AS trust_bar_tier_1,
	CASE
		WHEN course_partner IN ('BUx', 'SorbonneX', 'UBCx', 'USMx', 'GeorgetownX', 'AdelaideX') THEN 1 ELSE 0
	END AS trust_bar_tier_2,
	CASE
		WHEN course_partner IN ('RWTHx', 'ANUx') THEN 1 ELSE 0
	END AS trust_bar_tier_3,
	CASE
		WHEN course_partner IN ('MITx', 'HarvardX', 'BerkeleyX', 'CaltechX', 'OxfordX', 'ColumbiaX') THEN 1 ELSE 0
	END AS top_10_school,
	course_run_number,
	XSeries,
	ProfessionalCertificate,
	MicroMasters,
	NonProgram,
	audit_track,
	verified_track,
	professional_track,
	credit_track,
	cnt_available_tracks,
	YEAR(course_start_date) AS yr_started,
	QUARTER(course_start_date) AS qtr_started,
	MONTH(course_start_date) AS mth_started,
	DAYOFMONTH(course_start_date) AS day_of_month_started,
	DAYOFWEEK(course_start_date) AS day_of_week_started,
	YEAR(course_end_date) AS yr_ended,
	QUARTER(course_end_date) AS qtr_ended,
	MONTH(course_end_date) AS mth_ended,
	DAYOFMONTH(course_end_date) AS day_of_month_ended,
	DAYOFWEEK(course_end_date) AS day_of_week_ended,
	DATEDIFF(day, course_start_date, course_end_date) AS course_open_length,
	DATEDIFF(day, course_start_date, course_verification_end_date) AS course_verification_window,
	sum_enrolls,
	sum_enrolls/DATEDIFF(day, course_start_date, course_end_date) AS daily_enrollment_rate,
	sum_unenrolls/sum_enrolls AS pct_unenroll,
	sum_unenrolls,
	sum_unenrolls/DATEDIFF(day, course_start_date, course_end_date) AS daily_unenrollment_rate,
	sum_verifications,
	vtr,
	bookings_rank,
    bookings_per_course_rank,
	CAST(sum_bookings AS INT) AS sum_bookings
FROM
	ed_services.course_subjects a
LEFT JOIN
	business_intelligence.course_stats_summary b
ON
	a.course_id = b.course_id
LEFT JOIN
	business_intelligence.course_master c
ON
	a.course_id = c.course_id
LEFT JOIN
	ed_services.course_program d
ON
	a.course_id = d.course_id
LEFT JOIN
	ed_services.course_track e
ON
	a.course_id = e.course_id
LEFT JOIN
	ed_services.partner_rankings f
ON
	c.course_partner = f.org_id
WHERE
    course_end_date < GETDATE()
AND
    course_start_date < GETDATE();
"""

# Execute the Query from above
cur.execute(query)

# Dump the query results into a Pandas DataFrame
course_data = pd.DataFrame(cur.fetchall())

# %%
# Create multiclass based on quartiles
course_data['High Performing Course'] = 'Bad'

course_data['High Performing Course'][course_data['sum_bookings'] >= course_data['sum_bookings'].quantile(.75)] = "BlockBuster"
course_data['High Performing Course'][course_data['sum_bookings'] < course_data['sum_bookings'].quantile(.75)] = "Decent"
course_data['High Performing Course'][course_data['sum_bookings'] < course_data['sum_bookings'].quantile(.50)] = "Ok"
course_data['High Performing Course'][course_data['sum_bookings'] < course_data['sum_bookings'].quantile(.25)] = "Bad"
# Out:
# C:\Users\ochang\AppData\Local\Continuum\Anaconda2\lib\site-packages\ipykernel\__main__.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\ochang\AppData\Local\Continuum\Anaconda2\lib\site-packages\ipykernel\__main__.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\ochang\AppData\Local\Continuum\Anaconda2\lib\site-packages\ipykernel\__main__.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\ochang\AppData\Local\Continuum\Anaconda2\lib\site-packages\ipykernel\__main__.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %% [markdown]
# # Cells above run SQL in order to get data for courses that have ended and are no longer running

# %%
# Overall Course Bookings Distribution
ax = sns.boxplot(x=course_data['sum_bookings'])
ax.set(xlim=(0, 15000))
# Out:
# [(0, 15000)]

# %% [markdown]
# Shows a ton of outliers up top for courses with high bookings numbers
# - Majority of courses get under 12000
# - 25% of courses get between ~$5000 - ~$12000

# %%
# Course Bookings Distribution by Pacing Type
ax = sns.boxplot(x=course_data['sum_bookings'], y=course_data['pacing_type'])
ax.set(xlim=(0, 20000))
# Out:
# [(0, 20000)]

# %%
course_data.groupby(['pacing_type']).count()
# So not a lot of self paced courses here, could really muck up the descriptive stats
# Out:
#                   course_id  Architecture  ArtCulture  BiologyLifeSciences  \
# pacing_type
# instructor_paced        535           535         535                  535
# self_paced               58            58          58                   58
#
#                   BusinessManagement  Chemistry  Communication  \
# pacing_type
# instructor_paced                 535        535            535
# self_paced                        58         58             58
#
#                   ComputerScience  DataAnalysisStatistics  Design  \
# pacing_type
# instructor_paced              535                     535     535
# self_paced                     58                      58      58
#
#                       ...       sum_enrolls  daily_enrollment_rate  \
# pacing_type           ...
# instructor_paced      ...               535                    535
# self_paced            ...                58                     58
#
#                   pct_unenroll  sum_unenrolls  daily_unenrollment_rate  \
# pacing_type
# instructor_paced           535            535                      535
# self_paced                  58             58                       58
#
#                   sum_verifications  vtr  bookings_rank  \
# pacing_type
# instructor_paced                535  535            535
# self_paced                       58   58             58
#
#                   bookings_per_course_rank  sum_bookings
# pacing_type
# instructor_paced                       535           528
# self_paced                              58            58
#
# [2 rows x 71 columns]

# %% [markdown]
# Not a huge difference here in terms of distribution of bookings by pacing
# - a lot more outliers for instructor paced courses, this could be do us historically having more instructor paced courses, though now we have more self paced courses in the catalog
# - Median and IQR are pretty close together so maybe pacing type doesn't have nearly as much of an impact on total bookings

# %%
# Course Bookings Distribution by Level_type
ax = sns.boxplot(x=course_data['sum_bookings'], y=course_data['level_type'])
ax.set(xlim=(0, 15000))
# Out:
# [(0, 15000)]

# %%
course_data.groupby(['level_type']).count()
# Advanced has a super small sample size but Intermediate and Introductory don't look too bad
# Out:
#               course_id  Architecture  ArtCulture  BiologyLifeSciences  \
# level_type
# Advanced             53            53          53                   53
# Intermediate        153           153         153                  153
# Introductory        386           386         386                  386
#
#               BusinessManagement  Chemistry  Communication  ComputerScience  \
# level_type
# Advanced                      53         53             53               53
# Intermediate                 153        153            153              153
# Introductory                 386        386            386              386
#
#               DataAnalysisStatistics  Design      ...       sum_enrolls  \
# level_type                                        ...
# Advanced                          53      53      ...                53
# Intermediate                     153     153      ...               153
# Introductory                     386     386      ...               386
#
#               daily_enrollment_rate  pct_unenroll  sum_unenrolls  \
# level_type
# Advanced                         53            53             53
# Intermediate                    153           153            153
# Introductory                    386           386            386
#
#               daily_unenrollment_rate  sum_verifications  vtr  bookings_rank  \
# level_type
# Advanced                           53                 53   53             53
# Intermediate                      153                153  153            153
# Introductory                      386                386  386            386
#
#               bookings_per_course_rank  sum_bookings
# level_type
# Advanced                            53            53
# Intermediate                       153           151
# Introductory                       386           381
#
# [3 rows x 71 columns]

# %% [markdown]
# Interesting to see that Intermediate level_type has a higher max and larger spread for bookings
# - So Intermediate courses seem to pull in more bookings
# - Would be interesting to see the distribution of courses to make sure that sample sizes aren't playing a role here

# %%
# Course Bookings Distribution by Pacing Type and Level Type
ax = sns.boxplot(x=course_data['sum_bookings'], y=course_data['pacing_type'], hue=course_data['level_type'])
ax.set(xlim=(0,15000))
# Out:
# [(0, 15000)]

# %%
ax = sns.boxplot(x=course_data['course_open_length'], y=course_data['pacing_type'], hue=course_data['level_type'])
ax.set(xlim=(0, 400))
# Out:
# [(0, 400)]

# %%
ax = sns.boxplot(x=course_data['course_verification_window'], y=course_data['pacing_type'], hue=course_data['level_type'])
ax.set(xlim=(0, 400))
# Out:
# [(0, 400)]

# %%
course_data.mean()
# Out:
# Architecture                      0.011804
# ArtCulture                        0.101180
# BiologyLifeSciences               0.097808
# BusinessManagement                0.123103
# Chemistry                         0.025295
# Communication                     0.033727
# ComputerScience                   0.158516
# DataAnalysisStatistics            0.077572
# Design                            0.008432
# EconomicsFinance                  0.092749
# EducationTeacherTraining          0.050590
# Electronics                       0.040472
# EnergyEarthSciences               0.010118
# Engineering                       0.173693
# EnvironmentalStudies              0.052277
# Ethics                            0.008432
# FoodNutrition                     0.013491
# HealthSafety                      0.075885
# History                           0.109612
# Humanities                        0.195616
# Languag                           0.015177
# Law                               0.032040
# Literature                        0.084317
# Math                              0.067454
# Medicine                          0.062395
# Music                             0.018550
# PhilosophyEthics                  0.048904
# Physics                           0.102867
# Science                           0.124789
# SocialSciences                    0.173693
#                                   ...
# trust_bar_tier_3                  0.006745
# top_10_school                     0.276560
# course_run_number                 1.435076
# XSeries                           0.057336
# ProfessionalCertificate           0.000000
# MicroMasters                      0.003373
# NonProgram                        0.939292
# audit_track                       1.015203
# verified_track                    0.849662
# professional_track                0.016892
# credit_track                      0.000000
# cnt_available_tracks              1.881757
# yr_started                     2015.782462
# qtr_started                       2.308600
# mth_started                       5.922428
# day_of_month_started             14.696459
# day_of_week_started               3.158516
# yr_ended                       2015.949410
# qtr_ended                         2.487352
# mth_ended                         6.575042
# day_of_month_ended               16.826307
# day_of_week_ended                 3.802698
# course_open_length               82.755481
# course_verification_window       65.660040
# sum_enrolls                   10928.792580
# sum_unenrolls                  1868.300169
# sum_verifications               121.357504
# bookings_rank                    47.018550
# bookings_per_course_rank         65.301855
# sum_bookings                   6670.100683
# dtype: float64

# %%
course_data.median()
# Out:
# Architecture                     0.0
# ArtCulture                       0.0
# BiologyLifeSciences              0.0
# BusinessManagement               0.0
# Chemistry                        0.0
# Communication                    0.0
# ComputerScience                  0.0
# DataAnalysisStatistics           0.0
# Design                           0.0
# EconomicsFinance                 0.0
# EducationTeacherTraining         0.0
# Electronics                      0.0
# EnergyEarthSciences              0.0
# Engineering                      0.0
# EnvironmentalStudies             0.0
# Ethics                           0.0
# FoodNutrition                    0.0
# HealthSafety                     0.0
# History                          0.0
# Humanities                       0.0
# Languag                          0.0
# Law                              0.0
# Literature                       0.0
# Math                             0.0
# Medicine                         0.0
# Music                            0.0
# PhilosophyEthics                 0.0
# Physics                          0.0
# Science                          0.0
# SocialSciences                   0.0
#                                ...
# trust_bar_tier_3                 0.0
# top_10_school                    0.0
# course_run_number                1.0
# XSeries                          0.0
# ProfessionalCertificate          0.0
# MicroMasters                     0.0
# NonProgram                       1.0
# audit_track                      1.0
# verified_track                   1.0
# professional_track               0.0
# credit_track                     0.0
# cnt_available_tracks             2.0
# yr_started                    2016.0
# qtr_started                      2.0
# mth_started                      6.0
# day_of_month_started            15.0
# day_of_week_started              3.0
# yr_ended                      2016.0
# qtr_ended                        2.0
# mth_ended                        5.0
# day_of_month_ended              17.0
# day_of_week_ended                4.0
# course_open_length              58.0
# course_verification_window      37.0
# sum_enrolls                   6395.0
# sum_unenrolls                  990.0
# sum_verifications               40.0
# bookings_rank                   41.0
# bookings_per_course_rank        62.0
# sum_bookings                  1868.0
# dtype: float64

# %%
course_data.describe()
# Out:
#        Architecture  ArtCulture  BiologyLifeSciences  BusinessManagement  \
# count    593.000000  593.000000           593.000000          593.000000
# mean       0.011804    0.101180             0.097808            0.123103
# std        0.108096    0.301822             0.297305            0.328833
# min        0.000000    0.000000             0.000000            0.000000
# 25%        0.000000    0.000000             0.000000            0.000000
# 50%        0.000000    0.000000             0.000000            0.000000
# 75%        0.000000    0.000000             0.000000            0.000000
# max        1.000000    1.000000             1.000000            1.000000
#
#         Chemistry  Communication  ComputerScience  DataAnalysisStatistics  \
# count  593.000000     593.000000       593.000000              593.000000
# mean     0.025295       0.033727         0.158516                0.077572
# std      0.157153       0.180678         0.365533                0.267722
# min      0.000000       0.000000         0.000000                0.000000
# 25%      0.000000       0.000000         0.000000                0.000000
# 50%      0.000000       0.000000         0.000000                0.000000
# 75%      0.000000       0.000000         0.000000                0.000000
# max      1.000000       1.000000         1.000000                1.000000
#
#            Design  EconomicsFinance      ...        day_of_month_ended  \
# count  593.000000        593.000000      ...                593.000000
# mean     0.008432          0.092749      ...                 16.826307
# std      0.091514          0.290325      ...                  9.521057
# min      0.000000          0.000000      ...                  1.000000
# 25%      0.000000          0.000000      ...                  9.000000
# 50%      0.000000          0.000000      ...                 17.000000
# 75%      0.000000          0.000000      ...                 26.000000
# max      1.000000          1.000000      ...                 31.000000
#
#        day_of_week_ended  course_open_length  course_verification_window  \
# count         593.000000          593.000000                   503.00000
# mean            3.802698           82.755481                    65.66004
# std             1.764858           79.030395                   147.03220
# min             1.000000            1.000000                   -16.00000
# 25%             2.000000           42.000000                    21.00000
# 50%             4.000000           58.000000                    37.00000
# 75%             5.000000           89.000000                    58.00000
# max             7.000000          706.000000                  2126.00000
#
#          sum_enrolls  sum_unenrolls  sum_verifications  bookings_rank  \
# count     593.000000     593.000000         593.000000     593.000000
# mean    10928.792580    1868.300169         121.357504      47.018550
# std     13729.778307    2689.973564         277.208601      42.465662
# min         1.000000       0.000000           0.000000       1.000000
# 25%      3309.000000     415.000000          10.000000       5.000000
# 50%      6395.000000     990.000000          40.000000      41.000000
# 75%     12514.000000    2141.000000         108.000000      77.000000
# max    104664.000000   25482.000000        2780.000000     145.000000
#
#        bookings_per_course_rank   sum_bookings
# count                593.000000     586.000000
# mean                  65.301855    6670.100683
# std                   44.134181   21524.127916
# min                    1.000000       0.000000
# 25%                   21.000000     579.000000
# 50%                   62.000000    1868.000000
# 75%                  103.000000    5115.250000
# max                  146.000000  405780.000000
#
# [8 rows x 64 columns]

# %%
course_data.corr()
# Out:
#                             Architecture  ArtCulture  BiologyLifeSciences  \
# Architecture                    1.000000    0.118654            -0.035986
# ArtCulture                      0.118654    1.000000            -0.091647
# BiologyLifeSciences            -0.035986   -0.091647             1.000000
# BusinessManagement             -0.040951   -0.125711            -0.123366
# Chemistry                      -0.017607   -0.018437             0.127727
# Communication                  -0.020419    0.061220            -0.061514
# ComputerScience                -0.047437   -0.130311            -0.080732
# DataAnalysisStatistics         -0.031695   -0.097297            -0.053038
# Design                         -0.010079    0.030217            -0.030362
# EconomicsFinance               -0.034945   -0.107276            -0.105275
# EducationTeacherTraining       -0.025229   -0.051934            -0.050102
# Electronics                    -0.022447   -0.068907            -0.038815
# EnergyEarthSciences            -0.011050   -0.033921             0.080160
# Engineering                    -0.008896   -0.109546            -0.031081
# EnvironmentalStudies            0.114624   -0.028554             0.101200
# Ethics                         -0.010079   -0.030939             0.031723
# FoodNutrition                  -0.012781    0.009237             0.010705
# HealthSafety                   -0.031320   -0.096145             0.205768
# History                         0.061609    0.293969            -0.079182
# Humanities                      0.024825    0.412522            -0.133748
# Languag                        -0.013568    0.187044            -0.040874
# Law                            -0.019885   -0.061043            -0.027669
# Literature                     -0.033165    0.300683            -0.079483
# Math                           -0.029395   -0.090236            -0.020650
# Medicine                       -0.028194   -0.086552             0.314064
# Music                          -0.015026    0.285423            -0.045266
# PhilosophyEthics               -0.024783   -0.024223            -0.048339
# Physics                        -0.037009   -0.113611            -0.018057
# Science                        -0.041270   -0.109770             0.133337
# SocialSciences                 -0.050110   -0.065264            -0.046066
# ...                                  ...         ...                  ...
# trust_bar_tier_3               -0.009007   -0.027649            -0.027134
# top_10_school                  -0.032670    0.055087            -0.076663
# course_run_number              -0.021825   -0.000782             0.036170
# XSeries                         0.040205   -0.082746             0.016471
# ProfessionalCertificate              NaN         NaN                  NaN
# MicroMasters                   -0.006358   -0.019518            -0.019154
# NonProgram                     -0.037599    0.085297            -0.011385
# audit_track                     0.063241    0.002227            -0.048425
# verified_track                  0.046013    0.000317             0.027339
# professional_track             -0.014339    0.042847             0.089081
# credit_track                         NaN         NaN                  NaN
# cnt_available_tracks            0.070298    0.015079             0.025987
# yr_started                      0.044107   -0.056027            -0.053287
# qtr_started                    -0.029066    0.045702             0.073876
# mth_started                    -0.029102    0.028498             0.072922
# day_of_month_started            0.019086    0.071404            -0.027068
# day_of_week_started            -0.027430    0.006934            -0.000917
# yr_ended                        0.023636   -0.024784            -0.057535
# qtr_ended                       0.021596   -0.030388             0.077771
# mth_ended                       0.017277   -0.011680             0.076885
# day_of_month_ended             -0.050526   -0.010921            -0.020842
# day_of_week_ended              -0.040897    0.031198             0.126982
# course_open_length             -0.029717    0.066119            -0.007895
# course_verification_window     -0.016594    0.059338            -0.051730
# sum_enrolls                    -0.004542   -0.067933            -0.047052
# sum_unenrolls                  -0.025881   -0.067668            -0.046743
# sum_verifications               0.011584   -0.073175            -0.009771
# bookings_rank                  -0.009615   -0.063407             0.047621
# bookings_per_course_rank       -0.037926   -0.063799             0.054261
# sum_bookings                    0.003099   -0.037325            -0.012898
#
#                             BusinessManagement  Chemistry  Communication  \
# Architecture                         -0.040951  -0.017607      -0.020419
# ArtCulture                           -0.125711  -0.018437       0.061220
# BiologyLifeSciences                  -0.123366   0.127727      -0.061514
# BusinessManagement                    1.000000  -0.060359      -0.041568
# Chemistry                            -0.060359   1.000000      -0.030097
# Communication                        -0.041568  -0.030097       1.000000
# ComputerScience                      -0.008034  -0.069919      -0.081087
# DataAnalysisStatistics                0.083221  -0.046716      -0.054178
# Design                                0.021582  -0.014855      -0.017228
# EconomicsFinance                      0.216383  -0.051508      -0.059735
# EducationTeacherTraining             -0.086490  -0.037187       0.042120
# Electronics                          -0.076950  -0.033085       0.009033
# EnergyEarthSciences                  -0.037881  -0.016287      -0.018888
# Engineering                          -0.036303  -0.017162      -0.036341
# EnvironmentalStudies                 -0.064939  -0.037835      -0.043878
# Ethics                               -0.034551  -0.014855      -0.017228
# FoodNutrition                        -0.043815   0.074256      -0.021848
# HealthSafety                         -0.049223   0.034947       0.017013
# History                              -0.115033  -0.056523      -0.035650
# Humanities                           -0.145952  -0.052368      -0.021484
# Languag                              -0.046513  -0.019998      -0.023193
# Law                                  -0.009879  -0.029309       0.019053
# Literature                           -0.113696  -0.048884      -0.023074
# Math                                 -0.080305  -0.043326      -0.050246
# Medicine                             -0.054214   0.091650      -0.009574
# Music                                -0.051510  -0.022147      -0.025685
# PhilosophyEthics                     -0.084961  -0.036529       0.044263
# Physics                              -0.126873   0.122215      -0.063263
# Science                              -0.094887   0.101656      -0.014014
# SocialSciences                        0.099177  -0.073859       0.160917
# ...                                        ...        ...            ...
# trust_bar_tier_3                      0.031828  -0.013276       0.098727
# top_10_school                         0.009307  -0.027573      -0.052861
# course_run_number                    -0.032667   0.035521      -0.033739
# XSeries                               0.040059  -0.039730      -0.046076
# ProfessionalCertificate                    NaN        NaN            NaN
# MicroMasters                          0.066732  -0.009371      -0.010868
# NonProgram                           -0.055202   0.040955       0.047496
# audit_track                          -0.049025  -0.011101      -0.012874
# verified_track                        0.040840   0.007671      -0.052142
# professional_track                    0.071538  -0.021135      -0.024511
# credit_track                               NaN        NaN            NaN
# cnt_available_tracks                  0.031972  -0.005988      -0.060639
# yr_started                            0.120005  -0.020888       0.014129
# qtr_started                           0.033050   0.040453      -0.057734
# mth_started                           0.032096   0.050110      -0.057837
# day_of_month_started                 -0.023033  -0.009968      -0.040983
# day_of_week_started                   0.100138   0.014509       0.006454
# yr_ended                              0.130211  -0.026908       0.031452
# qtr_ended                            -0.020454   0.062557      -0.046745
# mth_ended                            -0.021402   0.069888      -0.032510
# day_of_month_ended                   -0.007726  -0.030927      -0.010336
# day_of_week_ended                    -0.027934  -0.048970      -0.010881
# course_open_length                   -0.027764   0.002539       0.107639
# course_verification_window            0.146452  -0.004400      -0.041927
# sum_enrolls                          -0.019814  -0.054752       0.044690
# sum_unenrolls                        -0.065310  -0.043844       0.002555
# sum_verifications                     0.080256  -0.037509      -0.029583
# bookings_rank                        -0.108913   0.130537       0.020173
# bookings_per_course_rank             -0.109763   0.089740       0.036852
# sum_bookings                          0.139523  -0.028337      -0.030757
#
#                             ComputerScience  DataAnalysisStatistics    Design  \
# Architecture                      -0.047437               -0.031695 -0.010079
# ArtCulture                        -0.130311               -0.097297  0.030217
# BiologyLifeSciences               -0.080732               -0.053038 -0.030362
# BusinessManagement                -0.008034                0.083221  0.021582
# Chemistry                         -0.069919               -0.046716 -0.014855
# Communication                     -0.081087               -0.054178 -0.017228
# ComputerScience                    1.000000                0.236619  0.010474
# DataAnalysisStatistics             0.236619                1.000000 -0.026741
# Design                             0.010474               -0.026741  1.000000
# EconomicsFinance                  -0.091021               -0.005790 -0.029484
# EducationTeacherTraining           0.026220               -0.066941  0.231171
# Electronics                        0.145165                0.004424 -0.018939
# EnergyEarthSciences               -0.043880               -0.029319 -0.009323
# Engineering                        0.130078               -0.033113  0.006403
# EnvironmentalStudies              -0.101936               -0.068108 -0.021658
# Ethics                            -0.040023               -0.026741 -0.008503
# FoodNutrition                     -0.050755               -0.033912 -0.010784
# HealthSafety                      -0.106938                0.035930 -0.026425
# History                           -0.137504               -0.101748 -0.032355
# Humanities                        -0.202394               -0.111221 -0.045474
# Languag                           -0.053880               -0.036000 -0.011448
# Law                               -0.052746               -0.052760 -0.016777
# Literature                        -0.115087               -0.087998 -0.027982
# Math                               0.104187                0.324177 -0.024801
# Medicine                          -0.073784                0.081577 -0.023788
# Music                             -0.025449               -0.039868 -0.012677
# PhilosophyEthics                  -0.098418               -0.065757 -0.020910
# Physics                           -0.086171               -0.077444 -0.031225
# Science                           -0.121973                0.004954 -0.034820
# SocialSciences                    -0.089302                0.000168  0.006403
# ...                                     ...                     ...       ...
# trust_bar_tier_3                  -0.035767               -0.023898 -0.007599
# top_10_school                      0.031003                0.060297  0.066680
# course_run_number                  0.025328               -0.050685  0.118963
# XSeries                            0.151149                0.118298  0.215247
# ProfessionalCertificate                 NaN                     NaN       NaN
# MicroMasters                      -0.025248               -0.016870 -0.005364
# NonProgram                        -0.141024               -0.111076 -0.208255
# audit_track                        0.011951                0.094323 -0.089950
# verified_track                     0.027568               -0.054456 -0.012824
# professional_track                 0.014783                0.010918  0.131140
# credit_track                            NaN                     NaN       NaN
# cnt_available_tracks               0.035434                0.006821 -0.018572
# yr_started                         0.017830               -0.127017  0.063765
# qtr_started                        0.003945                0.058696  0.023156
# mth_started                        0.020382                0.051989  0.002065
# day_of_month_started              -0.037273               -0.009031  0.001049
# day_of_week_started               -0.095744               -0.054030  0.110694
# yr_ended                          -0.006424               -0.124552  0.067069
# qtr_ended                          0.065085               -0.024252 -0.023072
# mth_ended                          0.055205               -0.020099 -0.025032
# day_of_month_ended                 0.022000                0.035778  0.017193
# day_of_week_ended                 -0.092833               -0.042630  0.041694
# course_open_length                -0.044265               -0.082611 -0.021436
# course_verification_window        -0.020560               -0.054436 -0.007412
# sum_enrolls                        0.113840                0.245542 -0.006462
# sum_unenrolls                      0.104145                0.228812 -0.016060
# sum_verifications                  0.058836                0.145454 -0.001384
# bookings_rank                     -0.022933               -0.065056 -0.073933
# bookings_per_course_rank          -0.044435               -0.064745 -0.056674
# sum_bookings                       0.052679                0.110300  0.015800
#
#                             EconomicsFinance      ...       \
# Architecture                       -0.034945      ...
# ArtCulture                         -0.107276      ...
# BiologyLifeSciences                -0.105275      ...
# BusinessManagement                  0.216383      ...
# Chemistry                          -0.051508      ...
# Communication                      -0.059735      ...
# ComputerScience                    -0.091021      ...
# DataAnalysisStatistics             -0.005790      ...
# Design                             -0.029484      ...
# EconomicsFinance                    1.000000      ...
# EducationTeacherTraining           -0.073807      ...
# Electronics                        -0.065666      ...
# EnergyEarthSciences                -0.032326      ...
# Engineering                        -0.131247      ...
# EnvironmentalStudies                0.003259      ...
# Ethics                             -0.029484      ...
# FoodNutrition                      -0.037390      ...
# HealthSafety                       -0.025766      ...
# History                            -0.112184      ...
# Humanities                         -0.157674      ...
# Languag                            -0.039692      ...
# Law                                 0.040859      ...
# Literature                         -0.097023      ...
# Math                               -0.039634      ...
# Medicine                           -0.082481      ...
# Music                              -0.043957      ...
# PhilosophyEthics                    0.008364      ...
# Physics                            -0.108268      ...
# Science                            -0.120732      ...
# SocialSciences                      0.160307      ...
# ...                                      ...      ...
# trust_bar_tier_3                   -0.026349      ...
# top_10_school                      -0.080720      ...
# course_run_number                   0.047184      ...
# XSeries                            -0.078854      ...
# ProfessionalCertificate                  NaN      ...
# MicroMasters                       -0.018600      ...
# NonProgram                          0.081286      ...
# audit_track                        -0.022035      ...
# verified_track                      0.069496      ...
# professional_track                  0.003203      ...
# credit_track                             NaN      ...
# cnt_available_tracks                0.050174      ...
# yr_started                          0.123451      ...
# qtr_started                        -0.009884      ...
# mth_started                        -0.007943      ...
# day_of_month_started                0.030465      ...
# day_of_week_started                 0.044934      ...
# yr_ended                            0.115568      ...
# qtr_ended                           0.011114      ...
# mth_ended                          -0.002634      ...
# day_of_month_ended                  0.038226      ...
# day_of_week_ended                   0.022588      ...
# course_open_length                 -0.023967      ...
# course_verification_window         -0.000613      ...
# sum_enrolls                        -0.030782      ...
# sum_unenrolls                      -0.076580      ...
# sum_verifications                   0.176628      ...
# bookings_rank                       0.011506      ...
# bookings_per_course_rank           -0.004430      ...
# sum_bookings                        0.038598      ...
#
#                             day_of_month_ended  day_of_week_ended  \
# Architecture                         -0.050526          -0.040897
# ArtCulture                           -0.010921           0.031198
# BiologyLifeSciences                  -0.020842           0.126982
# BusinessManagement                   -0.007726          -0.027934
# Chemistry                            -0.030927          -0.048970
# Communication                        -0.010336          -0.010881
# ComputerScience                       0.022000          -0.092833
# DataAnalysisStatistics                0.035778          -0.042630
# Design                                0.017193           0.041694
# EconomicsFinance                      0.038226           0.022588
# EducationTeacherTraining             -0.032992           0.004010
# Electronics                           0.024439           0.027832
# EnergyEarthSciences                   0.019559           0.020868
# Engineering                           0.020537          -0.026954
# EnvironmentalStudies                  0.004288          -0.094022
# Ethics                               -0.064232          -0.000141
# FoodNutrition                         0.002135          -0.044943
# HealthSafety                         -0.026899           0.075398
# History                              -0.080977           0.075992
# Humanities                           -0.071882           0.091340
# Languag                               0.015316           0.013890
# Law                                   0.007348          -0.028516
# Literature                            0.071889           0.051161
# Math                                 -0.007105          -0.042354
# Medicine                              0.028163           0.064448
# Music                                 0.003824           0.036645
# PhilosophyEthics                     -0.064903          -0.045576
# Physics                               0.036526          -0.056553
# Science                              -0.000615           0.059612
# SocialSciences                        0.005096          -0.067343
# ...                                        ...                ...
# trust_bar_tier_3                     -0.052637          -0.060880
# top_10_school                         0.053297           0.079870
# course_run_number                    -0.037016          -0.042316
# XSeries                              -0.169345           0.027594
# ProfessionalCertificate                    NaN                NaN
# MicroMasters                          0.025522           0.023004
# NonProgram                            0.158673          -0.032450
# audit_track                           0.018784          -0.074659
# verified_track                       -0.035864          -0.024278
# professional_track                   -0.097330           0.059785
# credit_track                               NaN                NaN
# cnt_available_tracks                 -0.052212          -0.042969
# yr_started                           -0.115010          -0.025113
# qtr_started                           0.030367           0.054479
# mth_started                           0.043291           0.054638
# day_of_month_started                  0.080399          -0.030527
# day_of_week_started                  -0.048666           0.125467
# yr_ended                             -0.054936          -0.004190
# qtr_ended                            -0.109250           0.029994
# mth_ended                            -0.107821           0.024036
# day_of_month_ended                    1.000000          -0.028180
# day_of_week_ended                    -0.028180           1.000000
# course_open_length                    0.151176           0.047419
# course_verification_window            0.112685          -0.019597
# sum_enrolls                          -0.017220          -0.026628
# sum_unenrolls                         0.023055          -0.077159
# sum_verifications                    -0.047164           0.007464
# bookings_rank                         0.020726          -0.053999
# bookings_per_course_rank              0.035054          -0.074617
# sum_bookings                         -0.023333          -0.003944
#
#                             course_open_length  course_verification_window  \
# Architecture                         -0.029717                   -0.016594
# ArtCulture                            0.066119                    0.059338
# BiologyLifeSciences                  -0.007895                   -0.051730
# BusinessManagement                   -0.027764                    0.146452
# Chemistry                             0.002539                   -0.004400
# Communication                         0.107639                   -0.041927
# ComputerScience                      -0.044265                   -0.020560
# DataAnalysisStatistics               -0.082611                   -0.054436
# Design                               -0.021436                   -0.007412
# EconomicsFinance                     -0.023967                   -0.000613
# EducationTeacherTraining             -0.009322                    0.002252
# Electronics                          -0.031658                   -0.023198
# EnergyEarthSciences                   0.002020                   -0.013203
# Engineering                          -0.067466                   -0.044031
# EnvironmentalStudies                 -0.076796                   -0.053335
# Ethics                               -0.038018                   -0.023644
# FoodNutrition                        -0.026665                   -0.024181
# HealthSafety                          0.040323                   -0.048784
# History                               0.009768                    0.000430
# Humanities                            0.043736                    0.000407
# Languag                               0.230264                    0.141928
# Law                                  -0.031693                   -0.013274
# Literature                           -0.004978                   -0.012765
# Math                                  0.058904                   -0.006390
# Medicine                             -0.014300                   -0.039624
# Music                                 0.041577                    0.023891
# PhilosophyEthics                      0.044767                    0.016645
# Physics                              -0.042115                   -0.074834
# Science                              -0.075730                   -0.083072
# SocialSciences                        0.045051                   -0.024921
# ...                                        ...                         ...
# trust_bar_tier_3                      0.004691                   -0.006802
# top_10_school                         0.015713                    0.092018
# course_run_number                     0.060162                    0.018391
# XSeries                               0.035395                    0.003295
# ProfessionalCertificate                    NaN                         NaN
# MicroMasters                         -0.024868                   -0.019210
# NonProgram                           -0.028422                    0.001683
# audit_track                          -0.079948                   -0.047936
# verified_track                       -0.077285                         NaN
# professional_track                    0.064470                         NaN
# credit_track                               NaN                         NaN
# cnt_available_tracks                 -0.090986                   -0.047936
# yr_started                           -0.114176                    0.010479
# qtr_started                           0.017939                   -0.048457
# mth_started                           0.008512                   -0.050671
# day_of_month_started                 -0.104165                   -0.072560
# day_of_week_started                  -0.030287                    0.118530
# yr_ended                              0.171817                    0.191987
# qtr_ended                            -0.157730                   -0.130499
# mth_ended                            -0.146239                   -0.134526
# day_of_month_ended                    0.151176                    0.112685
# day_of_week_ended                     0.047419                   -0.019597
# course_open_length                    1.000000                    0.597178
# course_verification_window            0.597178                    1.000000
# sum_enrolls                           0.140403                    0.013093
# sum_unenrolls                         0.091421                   -0.012437
# sum_verifications                    -0.049934                   -0.012492
# bookings_rank                         0.024136                   -0.067353
# bookings_per_course_rank              0.045079                   -0.070455
# sum_bookings                         -0.051409                   -0.021750
#
#                             sum_enrolls  sum_unenrolls  sum_verifications  \
# Architecture                  -0.004542      -0.025881           0.011584
# ArtCulture                    -0.067933      -0.067668          -0.073175
# BiologyLifeSciences           -0.047052      -0.046743          -0.009771
# BusinessManagement            -0.019814      -0.065310           0.080256
# Chemistry                     -0.054752      -0.043844          -0.037509
# Communication                  0.044690       0.002555          -0.029583
# ComputerScience                0.113840       0.104145           0.058836
# DataAnalysisStatistics         0.245542       0.228812           0.145454
# Design                        -0.006462      -0.016060          -0.001384
# EconomicsFinance              -0.030782      -0.076580           0.176628
# EducationTeacherTraining      -0.046847      -0.082680          -0.029857
# Electronics                    0.050659       0.076858          -0.035393
# EnergyEarthSciences           -0.012116       0.006452           0.013497
# Engineering                    0.024012       0.052949          -0.051215
# EnvironmentalStudies          -0.050627      -0.039639           0.005879
# Ethics                         0.049970       0.037380           0.039367
# FoodNutrition                 -0.028612      -0.020414          -0.021631
# HealthSafety                   0.041852       0.019884          -0.029040
# History                        0.012774       0.024373          -0.030173
# Humanities                    -0.008715      -0.021445          -0.072468
# Languag                        0.171290       0.077675          -0.004493
# Law                           -0.028216       0.007397          -0.011263
# Literature                    -0.039056      -0.014973          -0.093538
# Math                           0.201040       0.293601          -0.008698
# Medicine                       0.033941       0.027061          -0.040810
# Music                         -0.029581      -0.027153          -0.026304
# PhilosophyEthics              -0.024862      -0.013591          -0.029737
# Physics                       -0.015062       0.078777          -0.101609
# Science                        0.023575       0.083300          -0.060215
# SocialSciences                -0.028776      -0.048438           0.053134
# ...                                 ...            ...                ...
# trust_bar_tier_3              -0.020294      -0.026991          -0.021901
# top_10_school                  0.239389       0.214776           0.190676
# course_run_number             -0.039319      -0.121590          -0.007572
# XSeries                        0.194274       0.086178           0.210396
# ProfessionalCertificate             NaN            NaN                NaN
# MicroMasters                  -0.020928      -0.024757           0.064824
# NonProgram                    -0.184058      -0.077890          -0.220574
# audit_track                    0.195902       0.282284           0.050978
# verified_track                -0.113509      -0.241420           0.184491
# professional_track            -0.103691      -0.090925          -0.057491
# credit_track                        NaN            NaN                NaN
# cnt_available_tracks          -0.026273      -0.087797           0.171761
# yr_started                    -0.319683      -0.512166           0.151617
# qtr_started                   -0.016303      -0.019555          -0.072145
# mth_started                   -0.029205      -0.034401          -0.054936
# day_of_month_started          -0.027072      -0.038192           0.000881
# day_of_week_started           -0.141082      -0.157509           0.024106
# yr_ended                      -0.279835      -0.488892           0.117839
# qtr_ended                     -0.043346      -0.053262           0.030810
# mth_ended                     -0.045131      -0.039313           0.015488
# day_of_month_ended            -0.017220       0.023055          -0.047164
# day_of_week_ended             -0.026628      -0.077159           0.007464
# course_open_length             0.140403       0.091421          -0.049934
# course_verification_window     0.013093      -0.012437          -0.012492
# sum_enrolls                    1.000000       0.859332           0.430174
# sum_unenrolls                  0.859332       1.000000           0.194971
# sum_verifications              0.430174       0.194971           1.000000
# bookings_rank                 -0.136476      -0.097062          -0.181987
# bookings_per_course_rank      -0.235518      -0.177178          -0.268588
# sum_bookings                   0.257358       0.094716           0.594408
#
#                             bookings_rank  bookings_per_course_rank  \
# Architecture                    -0.009615                 -0.037926
# ArtCulture                      -0.063407                 -0.063799
# BiologyLifeSciences              0.047621                  0.054261
# BusinessManagement              -0.108913                 -0.109763
# Chemistry                        0.130537                  0.089740
# Communication                    0.020173                  0.036852
# ComputerScience                 -0.022933                 -0.044435
# DataAnalysisStatistics          -0.065056                 -0.064745
# Design                          -0.073933                 -0.056674
# EconomicsFinance                 0.011506                 -0.004430
# EducationTeacherTraining         0.063190                  0.043788
# Electronics                     -0.036594                  0.031002
# EnergyEarthSciences              0.032123                  0.024528
# Engineering                     -0.073322                 -0.059969
# EnvironmentalStudies             0.045251                  0.033269
# Ethics                          -0.046115                 -0.068803
# FoodNutrition                    0.048181                  0.067486
# HealthSafety                     0.052704                  0.031830
# History                          0.001373                 -0.012072
# Humanities                      -0.118945                 -0.127836
# Languag                          0.032780                  0.036999
# Law                             -0.000531                  0.004183
# Literature                      -0.114990                 -0.114794
# Math                             0.027456                  0.019505
# Medicine                         0.058714                  0.025112
# Music                           -0.038647                 -0.042037
# PhilosophyEthics                 0.019804                  0.006072
# Physics                         -0.066217                 -0.041342
# Science                         -0.043941                  0.005747
# SocialSciences                   0.037252                  0.029264
# ...                                   ...                       ...
# trust_bar_tier_3                 0.026184                  0.031206
# top_10_school                   -0.614608                 -0.698537
# course_run_number               -0.053922                  0.021429
# XSeries                         -0.220640                 -0.240038
# ProfessionalCertificate               NaN                       NaN
# MicroMasters                    -0.043213                 -0.053166
# NonProgram                       0.225300                  0.246602
# audit_track                      0.050876                  0.028184
# verified_track                  -0.316446                 -0.273405
# professional_track              -0.123890                 -0.107740
# credit_track                          NaN                       NaN
# cnt_available_tracks            -0.290013                 -0.259362
# yr_started                      -0.119387                 -0.090228
# qtr_started                      0.043004                  0.019172
# mth_started                      0.048930                  0.023214
# day_of_month_started             0.041641                  0.053538
# day_of_week_started             -0.178552                 -0.141472
# yr_ended                        -0.110876                 -0.067203
# qtr_ended                        0.047848                  0.002922
# mth_ended                        0.040925                 -0.012221
# day_of_month_ended               0.020726                  0.035054
# day_of_week_ended               -0.053999                 -0.074617
# course_open_length               0.024136                  0.045079
# course_verification_window      -0.067353                 -0.070455
# sum_enrolls                     -0.136476                 -0.235518
# sum_unenrolls                   -0.097062                 -0.177178
# sum_verifications               -0.181987                 -0.268588
# bookings_rank                    1.000000                  0.862892
# bookings_per_course_rank         0.862892                  1.000000
# sum_bookings                    -0.192279                 -0.241464
#
#                             sum_bookings
# Architecture                    0.003099
# ArtCulture                     -0.037325
# BiologyLifeSciences            -0.012898
# BusinessManagement              0.139523
# Chemistry                      -0.028337
# Communication                  -0.030757
# ComputerScience                 0.052679
# DataAnalysisStatistics          0.110300
# Design                          0.015800
# EconomicsFinance                0.038598
# EducationTeacherTraining       -0.017619
# Electronics                    -0.033842
# EnergyEarthSciences             0.011462
# Engineering                    -0.036034
# EnvironmentalStudies            0.003178
# Ethics                          0.022294
# FoodNutrition                  -0.021919
# HealthSafety                    0.004708
# History                        -0.028941
# Humanities                     -0.040579
# Languag                        -0.001424
# Law                            -0.011763
# Literature                     -0.043173
# Math                           -0.021963
# Medicine                       -0.029078
# Music                          -0.027660
# PhilosophyEthics               -0.019116
# Physics                        -0.076284
# Science                        -0.056417
# SocialSciences                 -0.008061
# ...                                  ...
# trust_bar_tier_3               -0.015948
# top_10_school                   0.222579
# course_run_number              -0.006525
# XSeries                         0.185331
# ProfessionalCertificate              NaN
# MicroMasters                    0.567293
# NonProgram                     -0.318220
# audit_track                    -0.034897
# verified_track                  0.092929
# professional_track              0.047560
# credit_track                         NaN
# cnt_available_tracks            0.077517
# yr_started                      0.127670
# qtr_started                    -0.031226
# mth_started                    -0.025312
# day_of_month_started            0.026541
# day_of_week_started             0.064990
# yr_ended                        0.104998
# qtr_ended                       0.012927
# mth_ended                       0.008334
# day_of_month_ended             -0.023333
# day_of_week_ended              -0.003944
# course_open_length             -0.051409
# course_verification_window     -0.021750
# sum_enrolls                     0.257358
# sum_unenrolls                   0.094716
# sum_verifications               0.594408
# bookings_rank                  -0.192279
# bookings_per_course_rank       -0.241464
# sum_bookings                    1.000000
#
# [64 rows x 64 columns]

# %%
# Generating a Seaborn Correlation Matrix
corr = course_data.corr()

mask = np.zeros_like(corr, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True

f, ax = plt.subplots(figsize=(11, 9))

cmap = sns.diverging_palette(220, 10, as_cmap=True)

sns.heatmap(corr, mask=mask, cmap=cmap, vmax=.5)

# %%
sns.regplot(x=course_data['sum_bookings'], y=course_data['sum_enrolls'], fit_reg=False)

# %%
sns.regplot(x=course_data['sum_bookings'], y=course_data['sum_unenrolls'], fit_reg=False)

# %%
sns.regplot(x=course_data['sum_bookings'], y=course_data['sum_verifications'], fit_reg=False)

# %%
sns.regplot(x=course_data['sum_bookings'], y=course_data['daily_enrollment_rate'], fit_reg=False)

# %%
sns.regplot(x=course_data['sum_bookings'], y=course_data['daily_unenrollment_rate'], fit_reg=False)

# %%
sns.regplot(x=course_data['daily_enrollment_rate'], y=course_data['daily_unenrollment_rate'], fit_reg=False)

# %%
# Impute Data for Clustering
course_data['cnt_subjects'] = course_data['cnt_subjects'].fillna(course_data['cnt_subjects'].median())
course_data['audit_track'] = course_data['audit_track'].fillna(course_data['audit_track'].median())
course_data['verified_track'] = course_data['verified_track'].fillna(course_data['verified_track'].median())
course_data['professional_track'] = course_data['professional_track'].fillna(course_data['professional_track'].median())
course_data['credit_track'] = course_data['credit_track'].fillna(course_data['credit_track'].median())
course_data['cnt_available_tracks'] = course_data['cnt_available_tracks'].fillna(course_data['cnt_available_tracks'].median())
course_data['course_open_length'] = course_data['course_open_length'].fillna(course_data['course_open_length'].median())
course_data['course_verification_window'] = course_data['course_verification_window'].fillna(course_data['course_verification_window'].median())
course_data['daily_enrollment_rate'] = course_data['daily_enrollment_rate'].fillna(course_data['daily_enrollment_rate'].median())
course_data['daily_unenrollment_rate'] = course_data['daily_unenrollment_rate'].fillna(course_data['daily_unenrollment_rate'].median())
course_data['vtr'] = course_data['vtr'].fillna(course_data['vtr'].median())
course_data['sum_bookings'] = course_data['sum_bookings'].fillna(course_data['sum_bookings'].mean())

course_data = pd.concat([course_data, pd.get_dummies(course_data['pacing_type'])], axis=1)
course_data = pd.concat([course_data, pd.get_dummies(course_data['level_type'])], axis=1)

# %%
# Course Clustering using Course Open Length and Bookings

from collections import Counter
import random

from sklearn.cluster import KMeans

def set_colors(labels, colors='rgbykcm'):
    colored_labels=[]
    for label in labels:
        colored_labels.append(colors[label])
    return colored_labels

# %%
estimator = KMeans(n_clusters=6)
X = course_data[["course_open_length", "sum_bookings"]]
estimator.fit(X)

labels = estimator.labels_
print Counter(labels)
# Out:
# Counter({0: 466, 5: 84, 3: 30, 2: 7, 4: 5, 1: 1})

# %%
colors = set_colors(labels)
plt.scatter(course_data['course_open_length'], course_data['sum_bookings'], c=colors)
plt.xlabel("course_open_length")
plt.ylabel("sum_bookings")
plt.show()

# %%
estimator = KMeans(n_clusters=3)
X = course_data[["course_verification_window", "sum_bookings"]]
estimator.fit(X)

labels = estimator.labels_
print Counter(labels)
# Out:
# Counter({0: 580, 2: 12, 1: 1})

# %%
colors = set_colors(labels)
plt.scatter(course_data['course_verification_window'], course_data['sum_bookings'], c=colors)
plt.xlabel("course_verification_window")
plt.ylabel("sum_bookings")
plt.show()

# %%
estimator = KMeans(n_clusters=6)
X = course_data[["sum_enrolls", "sum_unenrolls"]]
estimator.fit(X)

labels = estimator.labels_
print Counter(labels)

colors = set_colors(labels)
plt.scatter(course_data['sum_enrolls'], course_data['sum_unenrolls'], c=colors)
plt.show()
# Out:
# Counter({2: 295, 0: 167, 3: 74, 5: 27, 1: 24, 4: 6})
