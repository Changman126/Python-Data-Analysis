# %%
# Import necessary libraries/modules
import vertica_python
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import os

from sklearn.model_selection import train_test_split
from sklearn import metrics

# %%
# Set up the Vertica Connection Information
username = os.getenv('VERTICA_USERNAME')
password = os.getenv('VERTICA_PASSWORD')

conn_info = {'host': 'warehouse.analytics.edx.org',
             'port': 5433,
             'user': username,
             'password': password,
             'database': 'warehouse',
             'read_timeout': 600,
             'unicode_error': 'strict',
             'ssl': False
            }

connection = vertica_python.connect(**conn_info)
cur = connection.cursor('dict')

# %%
preprocess_query="""
-- Create Binary Columns for each subject within a course_id
DROP TABLE IF EXISTS tmp_course_subjects;
CREATE LOCAL TEMPORARY TABLE IF NOT EXISTS tmp_course_subjects ON COMMIT PRESERVE ROWS AS
SELECT	
	DISTINCT course_id,
	CASE 
		WHEN subject_title = 'Architecture' THEN 1
		ELSE 0
	END AS Architecture,
	CASE 
		WHEN subject_title = 'Art & Culture' THEN 1
		ELSE 0
	END AS ArtCulture,
	CASE 
		WHEN subject_title = 'Biology & Life Sciences' THEN 1
		ELSE 0
	END AS BiologyLifeSciences,
	CASE 
		WHEN subject_title = 'Business & Management' THEN 1
		ELSE 0
	END AS BusinessManagement,
	CASE 
		WHEN subject_title = 'Chemistry' THEN 1
		ELSE 0
	END AS Chemistry,
	CASE 
		WHEN subject_title = 'Communication' THEN 1
		ELSE 0
	END AS Communication,
	CASE 
		WHEN subject_title = 'Computer Science' THEN 1
		ELSE 0
	END AS ComputerScience,
	CASE 
		WHEN subject_title = 'Data Analysis & Statistics' THEN 1
		ELSE 0
	END AS DataAnalysisStatistics,
	CASE 
		WHEN subject_title = 'Design' THEN 1
		ELSE 0
	END AS Design,
	CASE 
		WHEN subject_title = 'Economics & Finance' THEN 1
		ELSE 0
	END AS EconomicsFinance,
	CASE 
		WHEN subject_title = 'Education & Teacher Training' THEN 1
		ELSE 0
	END AS EducationTeacherTraining,
	CASE 
		WHEN subject_title = 'Electronics' THEN 1
		ELSE 0
	END AS Electronics,
	CASE 
		WHEN subject_title = 'Energy & Earth Sciences' THEN 1
		ELSE 0
	END AS EnergyEarthSciences,
	CASE 
		WHEN subject_title = 'Engineering' THEN 1
		ELSE 0
	END AS Engineering,
	CASE 
		WHEN subject_title = 'Environmental Studies' THEN 1
		ELSE 0
	END AS EnvironmentalStudies,
	CASE 
		WHEN subject_title = 'Ethics' THEN 1
		ELSE 0
	END AS Ethics,
	CASE 
		WHEN subject_title = 'Food & Nutrition' THEN 1
		ELSE 0
	END AS FoodNutrition,
	CASE 
		WHEN subject_title = 'Health & Safety' THEN 1
		ELSE 0
	END AS HealthSafety,
	CASE 
		WHEN subject_title = 'History' THEN 1
		ELSE 0
	END AS History,
	CASE 
		WHEN subject_title = 'Humanities' THEN 1
		ELSE 0
	END AS Humanities,
		CASE 
		WHEN subject_title = 'Language' THEN 1
		ELSE 0
	END AS Languag,
		CASE 
		WHEN subject_title = 'Law' THEN 1
		ELSE 0
	END AS Law,
		CASE 
		WHEN subject_title = 'Literature' THEN 1
		ELSE 0
	END AS Literature,
		CASE 
		WHEN subject_title = 'Math' THEN 1
		ELSE 0
	END AS Math,
		CASE 
		WHEN subject_title = 'Medicine' THEN 1
		ELSE 0
	END AS Medicine,
		CASE 
		WHEN subject_title = 'Music' THEN 1
		ELSE 0
	END AS Music,
		CASE 
		WHEN subject_title = 'Philosophy & Ethics' THEN 1
		ELSE 0
	END AS PhilosophyEthics,
		CASE 
		WHEN subject_title = 'Physics' THEN 1
		ELSE 0
	END AS Physics,
		CASE 
		WHEN subject_title = 'Science' THEN 1
		ELSE 0
	END AS Science,
		CASE 
		WHEN subject_title = 'Social Sciences' THEN 1
		ELSE 0
	END AS SocialSciences
FROM
	production.d_course_subjects;
	
--Roll up the subjects at the course_id level
DROP TABLE IF EXISTS ed_services.course_subjects;	
CREATE TABLE IF NOT EXISTS ed_services.course_subjects AS
SELECT
	course_id,
	SUM(Architecture) AS Architecture,
	SUM(ArtCulture) AS ArtCulture,
	SUM(BiologyLifeSciences) AS BiologyLifeSciences,
	SUM(BusinessManagement) AS BusinessManagement,
	SUM(Chemistry) AS Chemistry,
	SUM(Communication) AS Communication,
	SUM(ComputerScience) AS ComputerScience,
	SUM(DataAnalysisStatistics) AS DataAnalysisStatistics,
	SUM(Design) AS Design,
	SUM(EconomicsFinance) AS EconomicsFinance,
	SUM(EducationTeacherTraining) AS EducationTeacherTraining,
	SUM(Electronics) AS Electronics,
	SUM(EnergyEarthSciences) AS EnergyEarthSciences,
	SUM(Engineering) AS Engineering,
	SUM(EnvironmentalStudies) AS EnvironmentalStudies,
	SUM(Ethics) AS Ethics,
	SUM(FoodNutrition) AS FoodNutrition,
	SUM(HealthSafety) AS HealthSafety,
	SUM(History) AS History,
	SUM(Humanities) AS Humanities,
	SUM(Languag) AS Languag,
	SUM(Law) AS Law,
	SUM(Literature) AS Literature,
	SUM(Math) AS Math,
	SUM(Medicine) AS Medicine,
	SUM(Music) AS Music,
	SUM(PhilosophyEthics) AS PhilosophyEthics,
	SUM(Physics) AS Physics,
	SUM(Science) AS Science,
	SUM(SocialSciences) AS SocialSciences,
	COUNT(*) AS cnt_subjects
FROM
	tmp_course_subjects
GROUP BY
	course_id;
    
--Create Binary columns for programs 
DROP TABLE IF EXISTS tmp_course_program;	
CREATE LOCAL TEMPORARY TABLE IF NOT EXISTS tmp_course_program ON COMMIT PRESERVE ROWS AS
SELECT
	course_id,
	CASE
		WHEN program_type = 'XSeries' THEN 1
		ELSE 0
	END AS XSeries,
	CASE
		WHEN program_type = 'Professional Certificate' THEN 1
		ELSE 0
	END AS ProfessionalCertificate,
	CASE
		WHEN program_type = 'MicroMasters' THEN 1
		ELSE 0
	END AS MicroMasters
FROM
	production.d_program_course;

--Sum up the programs columns and add column for non program courses
DROP TABLE IF EXISTS course_program;
CREATE LOCAL TEMPORARY TABLE IF NOT EXISTS course_program ON COMMIT PRESERVE ROWS AS
SELECT
	course_id,
	SUM(XSeries) AS XSeries,
	SUM(ProfessionalCertificate) AS ProfessionalCertificate,
	SUM(MicroMasters) AS MicroMasters
FROM
	tmp_course_program
GROUP BY
	course_id;  
	
--Roll up into a program summary table	
DROP TABLE IF EXISTS ed_services.course_program;
CREATE TABLE IF NOT EXISTS ed_services.course_program AS
SELECT
	a.course_id,
	ISNULL(XSeries, 0) AS XSeries,
	ISNULL(ProfessionalCertificate, 0) AS ProfessionalCertificate,
	ISNULL(MicroMasters, 0) AS MicroMasters,
	CASE
		WHEN XSeries IS NULL THEN 1
		ELSE 0
	END AS NonProgram
FROM
	business_intelligence.course_master a
LEFT JOIN
	course_program b
ON
	a.course_id = b.course_id;

--Create binary column for course track
DROP TABLE IF EXISTS tmp_course_track;	
CREATE LOCAL TEMPORARY TABLE IF NOT EXISTS tmp_course_track ON COMMIT PRESERVE ROWS AS	
SELECT
	course_id,
	CASE
		WHEN course_seat_type IN ('honor', 'audit') THEN 1
		ELSE 0
	END AS audit_track,
	CASE
		WHEN course_seat_type = 'verified' THEN 1
		ELSE 0
	END AS verified_track,
	CASE
		WHEN course_seat_type IN ('no-id-professional', 'professional') THEN 1
		ELSE 0
	END AS professional_track,
	CASE
		WHEN course_seat_type = 'credit' THEN 1
		ELSE 0
	END AS credit_track
FROM
	production.d_course_seat;
	
--Roll up of course tracks per course_id	
DROP TABLE IF EXISTS ed_services.course_track;
CREATE TABLE IF NOT EXISTS ed_services.course_track AS
SELECT
	course_id,
	SUM(audit_track) AS audit_track,
	SUM(verified_track) AS verified_track,
	SUM(professional_track) AS professional_track,
	SUM(credit_track) AS credit_track,
	COUNT(*) AS cnt_available_tracks
FROM
	tmp_course_track
GROUP BY
	course_id;
    
--Partner Rankings    
DROP TABLE IF EXISTS ed_services.partner_rankings;	
CREATE TABLE IF NOT EXISTS ed_services.partner_rankings AS
SELECT
	org_id,
	course_run_count,
	course_count,
	sum_partner_enrolls,
	sum_partner_vtr,
	sum_partner_bookings,
	ISNULL(sum_partner_enrolls/course_run_count, 0) AS enrollments_per_course_run,
	ISNULL(sum_partner_bookings/course_run_count, 0) AS bookings_per_course_run,
	ROW_NUMBER() OVER (ORDER BY sum_partner_enrolls DESC) AS enrollment_rank,
	ROW_NUMBER() OVER (ORDER BY ISNULL(sum_partner_bookings,0) DESC) AS bookings_rank,
	ROW_NUMBER() OVER (ORDER BY ISNULL(sum_partner_vtr, 0) DESC) AS vtr_rank,
	ROW_NUMBER() OVER (ORDER BY ISNULL(sum_partner_enrolls/course_run_count, 0) DESC) AS enrolls_per_course_rank,
	ROW_NUMBER() OVER (ORDER BY ISNULL(sum_partner_bookings/course_run_count, 0) DESC) AS bookings_per_course_rank
FROM
	business_intelligence.partner_stats_summary
WHERE
	org_id IS NOT NULL;
    
DROP TABLE IF EXISTS ed_services.pre_course_grouping;
CREATE TABLE IF NOT EXISTS ed_services.pre_course_grouping AS
SELECT
	course_id,
	CASE
		WHEN subject_title IN ('Architecture', 'Art & Culture', 'Design', 'Education & Teacher Training', 'Ethics', 'Food & Nutrition', 'Health & Safety', 'History', 'Humanities', 'Language', 'Law', 'Literature', 'Music', 'Philosophy & Ethics', 'Social Sciences') THEN 1
		ELSE 0
	END AS LiberalArts,
	CASE
		WHEN subject_title IN ('Biology & Life Sciences', 'Chemistry', 'Computer Science', 'Data Analysis & Statistics', 'Electronics', 'Energy & Earth Sciences', 'Engineering', 'Environmental Studies', 'Math', 'Medicine', 'Physics', 'Science') THEN 1
		ELSE 0
	END AS STEM,
	CASE
		WHEN subject_title IN ('Business & Management', 'Communication', 'Economics & Finance') THEN 1
		ELSE 0
	END AS Business
FROM
	production.d_course_subjects;
	
DROP TABLE IF EXISTS ed_services.tmp_pre_course_grouping;
CREATE TABLE IF NOT EXISTS ed_services.tmp_pre_course_grouping AS
SELECT
	course_id,
	SUM(LiberalArts) AS LiberalArts,
	SUM(STEM) AS STEM,
	SUM(Business) AS Business
FROM
	ed_services.pre_course_grouping
GROUP BY
	course_id;
	
DROP TABLE IF EXISTS ed_services.course_grouping;
CREATE TABLE IF NOT EXISTS ed_services.course_grouping AS
SELECT
	course_id,
	CASE
		WHEN LiberalArts > 0 THEN 1
		ELSE 0
	END AS LiberalArts,
	CASE
		WHEN STEM > 0 THEN 1
		ELSE 0
	END AS STEM,
	CASE
		WHEN Business > 0 THEN 1
		ELSE 0
	END AS Business
FROM
	ed_services.tmp_pre_course_grouping;
    
DROP TABLE IF EXISTS ed_services.registrations;
CREATE TABLE IF NOT EXISTS ed_services.registrations AS
SELECT
	YEAR(user_account_creation_time) AS yr,
	QUARTER(user_account_creation_time) AS qtr,
	MONTH(user_account_creation_time) AS mth,
	COUNT(*) AS registrations
FROM
	production.d_user
GROUP BY
	1,
	2,
	3;    
"""

# Execute the Query from above
cur.execute(preprocess_query)

# %%
query = """
SELECT
	a.course_id,
	cnt_subjects,
	LiberalArts,
	STEM,
	Business,
	is_WL,
	level_type,
	pacing_type,
	course_partner,
	CASE
		WHEN course_partner IN ('MITx', 'HarvardX', 'BerkeleyX', 'UTArlingtonX', 'UTAustinX', 'UTHealthSPHx', 'UTPermianBasin', 'UTSanAntonioX', 'UTMBx', 'UQx', 'DelftX') THEN 1 ELSE 0
	END AS trust_bar_tier_1,
	CASE
		WHEN course_partner IN ('BUx', 'SorbonneX', 'UBCx', 'USMx', 'GeorgetownX', 'AdelaideX') THEN 1 ELSE 0
	END AS trust_bar_tier_2,
	CASE
		WHEN course_partner IN ('RWTHx', 'ANUx') THEN 1 ELSE 0
	END AS trust_bar_tier_3,
	CASE
		WHEN course_partner IN ('MITx', 'HarvardX', 'BerkeleyX', 'CaltechX', 'OxfordX', 'ColumbiaX') THEN 1 ELSE 0
	END AS top_10_school,
	course_run_number,
	XSeries,
	ProfessionalCertificate,
	MicroMasters,
	NonProgram,
	audit_track,
	verified_track,
	professional_track,
	credit_track,
	cnt_available_tracks,
	YEAR(course_start_date) AS yr_started,
	QUARTER(course_start_date) AS qtr_started,
	MONTH(course_start_date) AS mth_started,
	DAYOFMONTH(course_start_date) AS day_of_month_started,
	DAYOFWEEK(course_start_date) AS day_of_week_started,
	YEAR(course_end_date) AS yr_ended,
	QUARTER(course_end_date) AS qtr_ended,
	MONTH(course_end_date) AS mth_ended,
	DAYOFMONTH(course_end_date) AS day_of_month_ended,
	DAYOFWEEK(course_end_date) AS day_of_week_ended,
	DATEDIFF(day, course_start_date, course_end_date) AS course_open_length,
	DATEDIFF(day, course_start_date, course_verification_end_date) AS course_verification_window,
	registrations,
	TAs,
	sum_enrolls,
	sum_enrolls/DATEDIFF(day, course_start_date, course_end_date) AS daily_enrollment_rate,
	sum_unenrolls/sum_enrolls AS pct_unenroll,
	sum_unenrolls,
	sum_unenrolls/DATEDIFF(day, course_start_date, course_end_date) AS daily_unenrollment_rate,
	sum_verifications,
	vtr,
	bookings_rank,
    bookings_per_course_rank,
	CAST(sum_bookings AS INT) AS sum_bookings
FROM
	ed_services.course_subjects a
LEFT JOIN
	business_intelligence.course_stats_summary b
ON
	a.course_id = b.course_id
LEFT JOIN
	business_intelligence.course_master c
ON
	a.course_id = c.course_id
LEFT JOIN
	ed_services.course_program d
ON
	a.course_id = d.course_id
LEFT JOIN
	ed_services.course_track e
ON
	a.course_id = e.course_id
LEFT JOIN
	ed_services.partner_rankings f
ON
	c.course_partner = f.org_id
LEFT JOIN
	ed_services.course_grouping g
ON
	a.course_id = g.course_id
LEFT JOIN
	ed_services.registrations h
ON
	YEAR(course_start_date) = h.yr
AND
	QUARTER(course_start_date) = h.qtr
AND
	MONTH(course_start_date) = h.mth
LEFT JOIN
	ed_services.course_staff i
ON
	a.course_id = i.course_id
WHERE
    course_end_date < GETDATE()
AND
    course_start_date < GETDATE();
"""

# Execute the Query from above
cur.execute(query)

# Dump the query results into a Pandas DataFrame
course_data = pd.DataFrame(cur.fetchall())

# %%
# Impute Missing Values with Median
course_data['cnt_subjects'] = course_data['cnt_subjects'].fillna(course_data['cnt_subjects'].median())
course_data['audit_track'] = course_data['audit_track'].fillna(course_data['audit_track'].median())
course_data['verified_track'] = course_data['verified_track'].fillna(course_data['verified_track'].median())
course_data['professional_track'] = course_data['professional_track'].fillna(course_data['professional_track'].median())
course_data['credit_track'] = course_data['credit_track'].fillna(course_data['credit_track'].median())
course_data['cnt_available_tracks'] = course_data['cnt_available_tracks'].fillna(course_data['cnt_available_tracks'].median())
course_data['course_open_length'] = course_data['course_open_length'].fillna(course_data['course_open_length'].median())
course_data['course_verification_window'] = course_data['course_verification_window'].fillna(course_data['course_verification_window'].median())
course_data['daily_enrollment_rate'] = course_data['daily_enrollment_rate'].fillna(course_data['daily_enrollment_rate'].median())
course_data['daily_unenrollment_rate'] = course_data['daily_unenrollment_rate'].fillna(course_data['daily_unenrollment_rate'].median())
course_data['vtr'] = course_data['vtr'].fillna(course_data['vtr'].median())
course_data['sum_bookings'] = course_data['sum_bookings'].fillna(course_data['sum_bookings'].mean())
course_data['TAs'] = course_data['TAs'].fillna(course_data['TAs'].median())

# Create a Target Column to use for Training Predictions
#course_data['High Performing Course'] = (course_data.sum_bookings > course_data['sum_bookings'].median()).astype(int)
#course_data['High Performing Course'] = (course_data.sum_bookings > course_data['sum_bookings'].quantile(.85)).astype(int)

# Create Dummy Columns
course_data = pd.concat([course_data, pd.get_dummies(course_data['pacing_type'])], axis=1)
course_data = pd.concat([course_data, pd.get_dummies(course_data['level_type'])], axis=1)

# %%
# Create multiclass based on quartiles
print course_data['sum_bookings'].quantile(.50)

course_data['High Performing Course'] = 0

course_data['High Performing Course'][course_data['sum_bookings'] >= course_data['sum_bookings'].quantile(.75)] = 4
course_data['High Performing Course'][course_data['sum_bookings'] < course_data['sum_bookings'].quantile(.75)] = 3
course_data['High Performing Course'][course_data['sum_bookings'] < course_data['sum_bookings'].quantile(.50)] = 2
course_data['High Performing Course'][course_data['sum_bookings'] < course_data['sum_bookings'].quantile(.25)] = 1
# Out:
# 1926.0
# C:\Users\ochang\AppData\Local\Continuum\Anaconda2\lib\site-packages\ipykernel\__main__.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\ochang\AppData\Local\Continuum\Anaconda2\lib\site-packages\ipykernel\__main__.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\ochang\AppData\Local\Continuum\Anaconda2\lib\site-packages\ipykernel\__main__.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\ochang\AppData\Local\Continuum\Anaconda2\lib\site-packages\ipykernel\__main__.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
# Create multiclass based on quantiles

course_data['High Performing Course'] = 0

course_data['High Performing Course'][course_data['sum_bookings'] >= course_data['sum_bookings'].quantile(.66)] = 2
course_data['High Performing Course'][course_data['sum_bookings'] < course_data['sum_bookings'].quantile(.66)] = 1
course_data['High Performing Course'][course_data['sum_bookings'] < course_data['sum_bookings'].quantile(.33)] = 0
# Out:
# C:\Users\ochang\AppData\Local\Continuum\Anaconda2\lib\site-packages\ipykernel\__main__.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\ochang\AppData\Local\Continuum\Anaconda2\lib\site-packages\ipykernel\__main__.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\ochang\AppData\Local\Continuum\Anaconda2\lib\site-packages\ipykernel\__main__.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
# Check to make sure all rows have the same counts and that there are no missing values
#course_data.count()
#print course_data['sum_bookings'].quantile(.85)
course_data
# Out:
#                                          course_id  cnt_subjects  LiberalArts  \
# 0                         BerkeleyX/BFV101x/T12015             1            0
# 1                    BerkeleyX/CS-191x/2013_August             3            0
# 2                      BerkeleyX/ColWri3.4x/1T2015             2            1
# 3                      BerkeleyX/EECS149.1x/2T2014             2            0
# 4                       BerkeleyX/Stat_2.1x/1T2014             2            0
# 5                       BerkeleyX/Stat_2.2x/1T2014             2            0
# 6                       BerkeleyX/Stat_2.3x/2T2014             2            0
# 7                          CaltechX/Ay1001x/2T2014             1            0
# 8                         CooperUnion/CS.1x/1T2015             1            0
# 9                         CooperUnion/CS.2x/1T2015             1            0
# 10                      CornellX/Astro2290x/1T2014             3            0
# 11                      CornellX/ENGRI1280x/1T2014             6            1
# 12                       CornellX/PHIL2411x/2Q2015             3            1
# 13                          DavidsonX/D002/2014_T3             5            1
# 14                        DavidsonX/D003x.1/1T2015             3            0
# 15                        DavidsonX/D003x.2/2T2015             3            0
# 16                          EPFLx/BIO465.1x/4T2014             4            0
# 17                            HKUx/HKU02.1x/3T2014             3            1
# 18                       HamiltonX/ENG142x/2015_T1             3            1
# 19                    HamiltonX/RELST005.5x/1T2015             1            1
# 20                            HarvardX/AT1x/2T2014             3            1
# 21                        HarvardX/AmPoX.1/2014_T3             3            1
# 22                        HarvardX/AmPoX.2/2014_T3             3            1
# 23                         HarvardX/AmPoX.3/1T2015             3            1
# 24                         HarvardX/AmPoX.4/1T2015             3            1
# 25                   HarvardX/HDS1544.1x/2013_SOND             2            1
# 26                       HarvardX/HKS211.2x/3T2015             5            1
# 27                 HarvardX/HSPH-HMS214x/2013_SOND             4            1
# 28                       HarvardX/PH201x/2013_SOND             3            1
# 29                       HarvardX/PH207x/2012_Fall             4            1
# ..                                             ...           ...          ...
# 561         course-v1:UTHealthSPHx+INOV101x+2T2015             3            1
# 562         course-v1:UTennesseeX+ISEH2016x+3T2016             2            1
# 563            course-v1:UTokyoX+UTokyo004x+2T2016             1            1
# 564            course-v1:UTokyoX+UTokyo006x+1T2017             3            1
# 565         course-v1:UWashingtonX+ANTH378x+2T2015             1            1
# 566     course-v1:UWashingtonX+COMM220UWx_2+1T2015             2            1
# 567         course-v1:UWashingtonX+ECFS302x+1T2015             5            1
# 568         course-v1:UWashingtonX+ECFS311x+2T2015             4            1
# 569         course-v1:UWashingtonX+JSIS123x+1T2015             2            1
# 570  course-v1:University_of_TorontoX+D101x+1T2016             3            0
# 571               course-v1:UrFUx+ENGM1.1.x+3T2016             3            0
# 572             course-v1:VictoriaX+ICE101x+1T2017             3            1
# 573                    course-v1:WBGx+CE01x+1T2017             2            1
# 574                   course-v1:WBGx+F4D01x+1T2017             2            1
# 575                   course-v1:WBGx+KEE01x+3T2016             1            0
# 576            course-v1:WasedaX+CosDis101x+1T2016             2            0
# 577        course-v1:WellesleyX+ANTH207x_3+3T-2015             4            1
# 578          course-v1:WellesleyX+Italian1x+1T2016             2            1
# 579          course-v1:WellesleyX+Italian2x+1T2016             2            1
# 580          course-v1:WellesleyX+Italian3x+1T2016             2            1
# 581         course-v1:WellesleyX+PFinan101x+3T2016             3            0
# 582         course-v1:WellesleyX+SHKSPR_01X+1T2016             3            1
# 583         course-v1:WellesleyX+SHKSPR_02X+2T2016             3            1
# 584             course-v1:WellesleyX+SOC101+2T2016             3            1
# 585             course-v1:WellesleyX+SOC102+2T2016             3            1
# 586             course-v1:WellesleyX+SOC103+2T2016             3            1
# 587              course-v1:WestonHS+BIO101x+2T2016             1            0
# 588             course-v1:WestonHS+CALC360x+2T2015             1            0
# 589               course-v1:WitsX+ELEN7070x+2T2016             1            0
# 590                 course-v1:WitsX+HSD101x+2T2016             3            0
#
#      STEM  Business  is_WL    level_type       pacing_type  \
# 0       1         0      0  Introductory  instructor_paced
# 1       1         0      0  Intermediate  instructor_paced
# 2       0         0      0  Introductory  instructor_paced
# 3       1         0      0  Intermediate  instructor_paced
# 4       1         0      0  Introductory  instructor_paced
# 5       1         0      0  Introductory  instructor_paced
# 6       1         0      0  Intermediate  instructor_paced
# 7       1         0      0  Intermediate  instructor_paced
# 8       1         0      0  Introductory  instructor_paced
# 9       1         0      0  Introductory  instructor_paced
# 10      1         0      0  Intermediate  instructor_paced
# 11      1         0      0  Introductory  instructor_paced
# 12      0         0      0  Introductory  instructor_paced
# 13      1         0      0  Introductory  instructor_paced
# 14      1         0      0  Introductory  instructor_paced
# 15      1         0      0  Intermediate  instructor_paced
# 16      1         0      0      Advanced  instructor_paced
# 17      1         0      0  Introductory  instructor_paced
# 18      0         0      0  Introductory  instructor_paced
# 19      0         0      0  Introductory  instructor_paced
# 20      1         0      0  Intermediate  instructor_paced
# 21      0         0      0  Introductory  instructor_paced
# 22      0         0      0  Introductory  instructor_paced
# 23      0         0      0  Introductory  instructor_paced
# 24      0         0      0  Introductory  instructor_paced
# 25      0         0      0  Introductory  instructor_paced
# 26      0         0      0  Intermediate  instructor_paced
# 27      1         0      0  Intermediate  instructor_paced
# 28      1         0      0  Introductory  instructor_paced
# 29      1         0      0  Intermediate  instructor_paced
# ..    ...       ...    ...           ...               ...
# 561     1         1      0  Introductory  instructor_paced
# 562     0         0      0  Introductory        self_paced
# 563     0         0      0  Intermediate  instructor_paced
# 564     1         0      0  Introductory  instructor_paced
# 565     0         0      0  Introductory  instructor_paced
# 566     0         1      0  Introductory  instructor_paced
# 567     0         1      0  Introductory  instructor_paced
# 568     0         1      0  Introductory  instructor_paced
# 569     0         1      0  Introductory  instructor_paced
# 570     1         0      0  Introductory  instructor_paced
# 571     1         0      0  Intermediate  instructor_paced
# 572     1         0      0  Introductory  instructor_paced
# 573     0         1      0  Introductory  instructor_paced
# 574     0         1      0  Introductory  instructor_paced
# 575     0         1      0  Intermediate  instructor_paced
# 576     1         0      0  Introductory  instructor_paced
# 577     1         0      0  Introductory  instructor_paced
# 578     0         0      0  Introductory        self_paced
# 579     0         0      0  Intermediate        self_paced
# 580     0         0      0      Advanced        self_paced
# 581     1         1      0  Introductory  instructor_paced
# 582     0         0      0  Introductory  instructor_paced
# 583     0         0      0  Introductory  instructor_paced
# 584     0         1      0  Introductory        self_paced
# 585     0         1      0  Introductory        self_paced
# 586     0         1      0  Introductory        self_paced
# 587     1         0      0  Introductory        self_paced
# 588     1         0      0  Introductory  instructor_paced
# 589     1         0      0  Introductory  instructor_paced
# 590     1         0      0  Intermediate  instructor_paced
#
#              course_partner  trust_bar_tier_1           ...            \
# 0                 BerkeleyX                 1           ...
# 1                 BerkeleyX                 1           ...
# 2                 BerkeleyX                 1           ...
# 3                 BerkeleyX                 1           ...
# 4                 BerkeleyX                 1           ...
# 5                 BerkeleyX                 1           ...
# 6                 BerkeleyX                 1           ...
# 7                  CaltechX                 0           ...
# 8               CooperUnion                 0           ...
# 9               CooperUnion                 0           ...
# 10                 CornellX                 0           ...
# 11                 CornellX                 0           ...
# 12                 CornellX                 0           ...
# 13                DavidsonX                 0           ...
# 14                DavidsonX                 0           ...
# 15                DavidsonX                 0           ...
# 16                    EPFLx                 0           ...
# 17                     HKUx                 0           ...
# 18                HamiltonX                 0           ...
# 19                HamiltonX                 0           ...
# 20                 HarvardX                 1           ...
# 21                 HarvardX                 1           ...
# 22                 HarvardX                 1           ...
# 23                 HarvardX                 1           ...
# 24                 HarvardX                 1           ...
# 25                 HarvardX                 1           ...
# 26                 HarvardX                 1           ...
# 27                 HarvardX                 1           ...
# 28                 HarvardX                 1           ...
# 29                 HarvardX                 1           ...
# ..                      ...               ...           ...
# 561            UTHealthSPHx                 1           ...
# 562             UTennesseeX                 0           ...
# 563                 UTokyoX                 0           ...
# 564                 UTokyoX                 0           ...
# 565            UWashingtonX                 0           ...
# 566            UWashingtonX                 0           ...
# 567            UWashingtonX                 0           ...
# 568            UWashingtonX                 0           ...
# 569            UWashingtonX                 0           ...
# 570  University_of_TorontoX                 0           ...
# 571                   UrFUx                 0           ...
# 572               VictoriaX                 0           ...
# 573                    WBGx                 0           ...
# 574                    WBGx                 0           ...
# 575                    WBGx                 0           ...
# 576                 WasedaX                 0           ...
# 577              WellesleyX                 0           ...
# 578              WellesleyX                 0           ...
# 579              WellesleyX                 0           ...
# 580              WellesleyX                 0           ...
# 581              WellesleyX                 0           ...
# 582              WellesleyX                 0           ...
# 583              WellesleyX                 0           ...
# 584              WellesleyX                 0           ...
# 585              WellesleyX                 0           ...
# 586              WellesleyX                 0           ...
# 587                WestonHS                 0           ...
# 588                WestonHS                 0           ...
# 589                   WitsX                 0           ...
# 590                   WitsX                 0           ...
#
#                       vtr  bookings_rank  bookings_per_course_rank  \
# 0    0.004927385892116183              5                        21
# 1                   0E-18              5                        21
# 2    0.002199091042369154              5                        21
# 3                   0E-18              5                        21
# 4    0.037668484127203786              5                        21
# 5    0.037783171521035599              5                        21
# 6    0.023422532599962919              5                        21
# 7                   0E-18             56                        67
# 8    0.002474566950783613            112                       124
# 9    0.001401541695865452            112                       124
# 10                  0E-18             24                        31
# 11                  0E-18             24                        31
# 12   0.018410286382232613             24                        31
# 13   0.002787342187243810             57                        63
# 14   0.005302976737608711             57                        63
# 15   0.004380143350146005             57                        63
# 16   0.012452625879805089             48                       118
# 17   0.006861294228440737             54                        54
# 18                  0E-18            115                       111
# 19   0.007105119329568227            115                       111
# 20   0.005863972948679536              4                        15
# 21   0.011713030746705710              4                        15
# 22   0.006475285991797971              4                        15
# 23   0.005621058404167809              4                        15
# 24   0.007062033544659337              4                        15
# 25                  0E-18              4                        15
# 26   0.027046677330231205              4                        15
# 27                  0E-18              4                        15
# 28                  0E-18              4                        15
# 29                  0E-18              4                        15
# ..                    ...            ...                       ...
# 561                 0E-18            110                       108
# 562  0.022807017543859649            120                       117
# 563  0.030751134263149051             82                        93
# 564  0.032690246516613076             82                        93
# 565                 0E-18            127                       138
# 566                 0E-18            127                       138
# 567                 0E-18            127                       138
# 568                 0E-18            127                       138
# 569                 0E-18            127                       138
# 570                 0E-18             55                        62
# 571  0.003376477208778841            141                       133
# 572  0.024611177576482653            107                        33
# 573  0.099123099123099123             90                        59
# 574  0.130076735916151975             90                        59
# 575  0.063838383838383838             90                        59
# 576                 0E-18            122                       119
# 577  0.006544502617801047             63                        96
# 578  0.005529828846708395             63                        96
# 579  0.007498557969621227             63                        96
# 580  0.007290513104466593             63                        96
# 581  0.001971788260276050             63                        96
# 582  0.008720930232558140             63                        96
# 583  0.006750675067506751             63                        96
# 584  0.011844131232974061             63                        96
# 585  0.011810044753853804             63                        96
# 586  0.006404992609623912             63                        96
# 587  0.001694915254237288            131                       136
# 588  0.005194805194805195            131                       136
# 589  0.008535242290748899             93                        72
# 590  0.010786516853932584             93                        72
#
#      sum_bookings  instructor_paced  self_paced  Advanced  Intermediate  \
# 0           965.0                 1           0         0             0
# 1           125.0                 1           0         0             1
# 2           875.0                 1           0         0             0
# 3            40.0                 1           0         0             1
# 4         31069.0                 1           0         0             0
# 5         11896.0                 1           0         0             0
# 6          9411.0                 1           0         0             1
# 7            69.0                 1           0         0             1
# 8           970.0                 1           0         0             0
# 9           210.0                 1           0         0             0
# 10          260.0                 1           0         0             1
# 11          198.0                 1           0         0             0
# 12         6809.0                 1           0         0             0
# 13          930.0                 1           0         0             0
# 14         1856.0                 1           0         0             0
# 15          980.0                 1           0         0             1
# 16         1105.0                 1           0         1             0
# 17         3220.0                 1           0         0             0
# 18          130.0                 1           0         0             0
# 19         1365.0                 1           0         0             0
# 20        20576.0                 1           0         0             1
# 21         1420.0                 1           0         0             0
# 22         1202.0                 1           0         0             0
# 23         1430.0                 1           0         0             0
# 24         4190.0                 1           0         0             0
# 25          786.0                 1           0         0             0
# 26        16121.0                 1           0         0             1
# 27          181.0                 1           0         0             1
# 28           76.0                 1           0         0             0
# 29          130.0                 1           0         0             1
# ..            ...               ...         ...       ...           ...
# 561         240.0                 1           0         0             0
# 562        1176.0                 0           1         0             0
# 563        8706.0                 1           0         0             1
# 564        2661.0                 1           0         0             0
# 565          71.0                 1           0         0             0
# 566         900.0                 1           0         0             0
# 567         135.0                 1           0         0             0
# 568        1108.0                 1           0         0             0
# 569          75.0                 1           0         0             0
# 570          86.0                 1           0         0             0
# 571         412.0                 1           0         0             1
# 572        6985.0                 1           0         0             0
# 573        4422.0                 1           0         0             0
# 574       13789.0                 1           0         0             0
# 575        2342.0                 1           0         0             1
# 576         110.0                 1           0         0             0
# 577         565.0                 1           0         0             0
# 578       16192.0                 0           1         0             0
# 579        3977.0                 0           1         0             1
# 580        3530.0                 0           1         1             0
# 581         641.0                 1           0         0             0
# 582         659.0                 1           0         0             0
# 583         757.0                 1           0         0             0
# 584        4546.0                 0           1         0             0
# 585        4502.0                 0           1         0             0
# 586        1861.0                 0           1         0             0
# 587          50.0                 0           1         0             0
# 588          89.0                 1           0         0             0
# 589        1206.0                 1           0         0             0
# 590        1039.0                 1           0         0             1
#
#      Introductory  High Performing Course
# 0               1                       1
# 1               0                       1
# 2               1                       1
# 3               0                       1
# 4               1                       3
# 5               1                       3
# 6               0                       3
# 7               0                       1
# 8               1                       1
# 9               1                       1
# 10              0                       1
# 11              1                       1
# 12              1                       3
# 13              1                       1
# 14              1                       2
# 15              0                       1
# 16              0                       2
# 17              1                       2
# 18              1                       1
# 19              1                       2
# 20              0                       3
# 21              1                       2
# 22              1                       2
# 23              1                       2
# 24              1                       3
# 25              1                       1
# 26              0                       3
# 27              0                       1
# 28              1                       1
# 29              0                       1
# ..            ...                     ...
# 561             1                       1
# 562             1                       2
# 563             0                       3
# 564             1                       2
# 565             1                       1
# 566             1                       1
# 567             1                       1
# 568             1                       2
# 569             1                       1
# 570             1                       1
# 571             0                       1
# 572             1                       3
# 573             1                       3
# 574             1                       3
# 575             0                       2
# 576             1                       1
# 577             1                       1
# 578             1                       3
# 579             0                       3
# 580             0                       3
# 581             1                       1
# 582             1                       1
# 583             1                       1
# 584             1                       3
# 585             1                       3
# 586             1                       2
# 587             1                       1
# 588             1                       1
# 589             1                       2
# 590             0                       2
#
# [591 rows x 53 columns]

# %%
# Create feature columns which will be used as factors to determine [y]
feature_cols = ['LiberalArts',
                'STEM',
                'Business',
                'cnt_subjects',
                'Advanced',
                'Intermediate',
                'Introductory',
                'self_paced',
                'instructor_paced',
                'course_run_number',
                'XSeries',
                #'ProfessionalCertificate',
                'MicroMasters',
                'NonProgram',
                'cnt_available_tracks',
                'yr_started',
                #'qtr_started',
                'mth_started',
                'yr_ended',
                #'qtr_ended',
                'mth_ended',
                'course_open_length',
                'course_verification_window',
                'trust_bar_tier_1',
                'trust_bar_tier_2',
                #'trust_bar_tier_3',
                #'top_10_school',
                'bookings_per_course_rank',
                'registrations',
                'TAs'
                ]


X = course_data[feature_cols]
# y for classification
y = course_data['High Performing Course']
# y for regressor
#y = course_data['sum_bookings']
# For classification of 3 categories
#y = course_data['bookings_cat']

# %%
# Split the data into testing and training for above average bookings classification
X_train, X_test, y_train, y_test = train_test_split(course_data[feature_cols], course_data['High Performing Course'], test_size=0.20, random_state=42)

# %%
# Using the TPOT classifier to figure out the best model to use
from tpot import TPOTClassifier

tpot = TPOTClassifier(generations=10, verbosity=2)
tpot.fit(X_train, y_train)
print(tpot.score(X_test, y_test))

# Use TPOT on full dataset
#tpot.fit(X, y)
#print(tpot.score(X, y))
# Out:
# Warning: xgboost.XGBClassifier is not available and will not be used by TPOT.
# Generation 1 - Current best internal CV score: 0.531605121675
# Generation 2 - Current best internal CV score: 0.531605121675
# Generation 3 - Current best internal CV score: 0.538011460102
# Generation 4 - Current best internal CV score: 0.541951754386
# Generation 5 - Current best internal CV score: 0.541951754386
# Generation 6 - Current best internal CV score: 0.546883842671
# Generation 7 - Current best internal CV score: 0.552930814941
# Generation 8 - Current best internal CV score: 0.552930814941
# Generation 9 - Current best internal CV score: 0.552930814941
# Generation 10 - Current best internal CV score: 0.555037492926
# Best pipeline: RandomForestClassifier(input_matrix, RandomForestClassifier__bootstrap=False, RandomForestClassifier__criterion=DEFAULT, RandomForestClassifier__max_features=0.25, RandomForestClassifier__min_samples_leaf=2, RandomForestClassifier__min_samples_split=9, RandomForestClassifier__n_estimators=100)
# 0.512605042017

# %%
# Using the recommended pipeline from TPOT
from sklearn.ensemble import ExtraTreesClassifier

etc = ExtraTreesClassifier(bootstrap=False, max_features=0.5, min_samples_leaf=2, min_samples_split=5, n_estimators=100)

etc.fit(X_train, y_train)
# Out:
# ExtraTreesClassifier(bootstrap=False, class_weight=None, criterion='gini',
#            max_depth=None, max_features=0.5, max_leaf_nodes=None,
#            min_impurity_split=1e-07, min_samples_leaf=2,
#            min_samples_split=5, min_weight_fraction_leaf=0.0,
#            n_estimators=100, n_jobs=1, oob_score=False, random_state=None,
#            verbose=0, warm_start=False)

# %%
predictions = etc.predict(X_test)
prediction_probability = etc.predict_proba(X_test)

print metrics.confusion_matrix(y_test, predictions)
print metrics.classification_report(y_test, predictions)
print etc.score(X_test, y_test)
# Out:
# [[98  2]
#  [ 9  8]]
#              precision    recall  f1-score   support
#
#           0       0.92      0.98      0.95       100
#           1       0.80      0.47      0.59        17
#
# avg / total       0.90      0.91      0.90       117
#
# 0.905982905983

# %%
# Dispay the featured_cols (predictors of enrollment) in order of importance to the classifier
feature_importances = pd.Series(etc.feature_importances_, index=X.columns)
feature_importances.sort_values(inplace=True)
feature_importances.plot(kind="barh", figsize=(10,15));

# %%
# Trying to find the optimal number of trees/n_estimators
# Getting the cross validation score for each number o n_estimators/trees
from sklearn.cross_validation import cross_val_score

results = []
n_estimator_options = [50, 100, 200, 500, 1000, 2000, 4000, 8000]

for trees in n_estimator_options:
    etc = ExtraTreesClassifier(trees, bootstrap=True, oob_score=True, n_jobs=-1, random_state=42)
    etc.fit(X, y)
    print trees, "trees"
    scores = cross_val_score(etc, X, y, cv=10, scoring='roc_auc')
    roc = scores.mean()
    print "roc:", roc
    results.append(roc)
    print""
    
pd.Series(results, n_estimator_options).plot()

# %%
# Using Random Forest
from sklearn.ensemble import RandomForestClassifier

rf = RandomForestClassifier()

rf.fit(X_train, y_train)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_split=1e-07, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             n_estimators=10, n_jobs=1, oob_score=False, random_state=None,
#             verbose=0, warm_start=False)

# %%
rf_predictions = rf.predict(X_test)
rf_prediction_probability = rf.predict_proba(X_test)

print metrics.confusion_matrix(y_test, rf_predictions)
print metrics.classification_report(y_test, rf_predictions)
print rf.score(X_test, y_test)
# Out:
# [[45 15]
#  [17 40]]
#              precision    recall  f1-score   support
#
#           0       0.73      0.75      0.74        60
#           1       0.73      0.70      0.71        57
#
# avg / total       0.73      0.73      0.73       117
#
# 0.726495726496

# %%
# Dispay the featured_cols (predictors of enrollment) in order of importance to the classifier
feature_importances = pd.Series(rf.feature_importances_, index=X.columns)
feature_importances.sort_values(inplace=True)
feature_importances.plot(kind="barh", figsize=(10,15));

# %%
# Multiclass Best Model from TPOT
from sklearn.ensemble import RandomForestClassifier

rf = RandomForestClassifier(bootstrap=False, max_features=.25, min_samples_leaf=2, min_samples_split=9, n_estimators=100)

rf.fit(X_train, y_train)
# Out:
# RandomForestClassifier(bootstrap=False, class_weight=None, criterion='gini',
#             max_depth=None, max_features=0.25, max_leaf_nodes=None,
#             min_impurity_split=1e-07, min_samples_leaf=2,
#             min_samples_split=9, min_weight_fraction_leaf=0.0,
#             n_estimators=100, n_jobs=1, oob_score=False, random_state=None,
#             verbose=0, warm_start=False)

# %%
rf_predictions = rf.predict(X_test)
rf_prediction_probability = rf.predict_proba(X_test)

print metrics.confusion_matrix(y_test, rf_predictions, labels=[1, 2, 3])
print metrics.classification_report(y_test, rf_predictions)
print rf.score(X_test, y_test)
# Out:
# [[21 16  0]
#  [13 24  0]
#  [ 0  0  0]]
#              precision    recall  f1-score   support
#
#           0       0.80      0.74      0.77        38
#           1       0.55      0.49      0.52        43
#           2       0.52      0.63      0.57        38
#
# avg / total       0.62      0.61      0.61       119
#
# 0.613445378151

# %%
# Dispay the featured_cols (predictors of enrollment) in order of importance to the classifier
feature_importances = pd.Series(rf.feature_importances_, index=X.columns)
feature_importances.sort_values(inplace=True)
feature_importances.plot(kind="barh", figsize=(10,15));

# %%
# Test out model on courses that haven't ended yet
new_query = """
SELECT
	a.course_id,
    LiberalArts,
    STEM,
    Business,
	cnt_subjects,
	is_WL,
	level_type,
	pacing_type,
	course_partner,
	CASE
		WHEN course_partner IN ('MITx', 'HarvardX', 'BerkeleyX', 'UTArlingtonX', 'UTAustinX', 'UTHealthSPHx', 'UTPermianBasin', 'UTSanAntonioX', 'UTMBx', 'UQx', 'DelftX') THEN 1 ELSE 0
	END AS trust_bar_tier_1,
	CASE
		WHEN course_partner IN ('BUx', 'SorbonneX', 'UBCx', 'USMx', 'GeorgetownX', 'AdelaideX') THEN 1 ELSE 0
	END AS trust_bar_tier_2,
	CASE
		WHEN course_partner IN ('RWTHx', 'ANUx') THEN 1 ELSE 0
	END AS trust_bar_tier_3,
	CASE
		WHEN course_partner IN ('MITx', 'HarvardX', 'BerkeleyX', 'CaltechX', 'OxfordX', 'ColumbiaX') THEN 1 ELSE 0
	END AS top_10_school,
	course_run_number,
	XSeries,
	ProfessionalCertificate,
	MicroMasters,
	NonProgram,
	audit_track,
	verified_track,
	professional_track,
	credit_track,
	cnt_available_tracks,
	YEAR(course_start_date) AS yr_started,
	QUARTER(course_start_date) AS qtr_started,
	MONTH(course_start_date) AS mth_started,
	DAYOFMONTH(course_start_date) AS day_of_month_started,
	DAYOFWEEK(course_start_date) AS day_of_week_started,
	YEAR(course_end_date) AS yr_ended,
	QUARTER(course_end_date) AS qtr_ended,
	MONTH(course_end_date) AS mth_ended,
	DAYOFMONTH(course_end_date) AS day_of_month_ended,
	DAYOFWEEK(course_end_date) AS day_of_week_ended,
	DATEDIFF(day, course_start_date, course_end_date) AS course_open_length,
	DATEDIFF(day, course_start_date, course_verification_end_date) AS course_verification_window,
    TAs,
    registrations,
	sum_enrolls,
	sum_enrolls/DATEDIFF(day, course_start_date, course_end_date) AS daily_enrollment_rate,
	sum_unenrolls/sum_enrolls AS pct_unenroll,
	sum_unenrolls,
	sum_unenrolls/DATEDIFF(day, course_start_date, course_end_date) AS daily_unenrollment_rate,
	sum_verifications,
	vtr,
	bookings_rank,
    bookings_per_course_rank,
	CAST(sum_bookings AS INT) AS sum_bookings
FROM
	ed_services.course_subjects a
LEFT JOIN
	business_intelligence.course_stats_summary b
ON
	a.course_id = b.course_id
LEFT JOIN
	business_intelligence.course_master c
ON
	a.course_id = c.course_id
LEFT JOIN
	ed_services.course_program d
ON
	a.course_id = d.course_id
LEFT JOIN
	ed_services.course_track e
ON
	a.course_id = e.course_id
LEFT JOIN
	ed_services.partner_rankings f
ON
	c.course_partner = f.org_id
LEFT JOIN
	ed_services.course_grouping g
ON
	a.course_id = g.course_id
LEFT JOIN
	ed_services.registrations h
ON
	YEAR(course_start_date) = h.yr
AND
	QUARTER(course_start_date) = h.qtr
AND
	MONTH(course_start_date) = h.mth
LEFT JOIN
	ed_services.course_staff i
ON
	a.course_id = i.course_id
WHERE
    course_end_date > GETDATE()
AND
    course_start_date < GETDATE();
"""

# Execute the Query from above
cur.execute(new_query)

# Dump the query results into a Pandas DataFrame
new_course_data = pd.DataFrame(cur.fetchall())

# %%
new_course_data['course_verification_window'] = new_course_data['course_verification_window'].fillna(new_course_data['course_verification_window'].median())
new_course_data['sum_bookings'] = new_course_data['sum_bookings'].fillna(new_course_data['sum_bookings'].mean())
new_course_data['TAs'] = new_course_data['TAs'].fillna(new_course_data['TAs'].median())

#new_course_data['High Performing Course'] = (new_course_data.sum_bookings > new_course_data['sum_bookings'].quantile(.85)).astype(int)
#new_course_data['High Performing Course'] = (new_course_data.sum_bookings > new_course_data['sum_bookings'].median()).astype(int)


new_course_data = pd.concat([new_course_data, pd.get_dummies(new_course_data['pacing_type'])], axis=1)
new_course_data = pd.concat([new_course_data, pd.get_dummies(new_course_data['level_type'])], axis=1)

# %%
# Create multiclass based on quartiles
new_course_data['High Performing Course'] = 0

new_course_data['High Performing Course'][new_course_data['sum_bookings'] >= new_course_data['sum_bookings'].quantile(.75)] = 4
new_course_data['High Performing Course'][new_course_data['sum_bookings'] < new_course_data['sum_bookings'].quantile(.75)] = 3
new_course_data['High Performing Course'][new_course_data['sum_bookings'] < new_course_data['sum_bookings'].quantile(.50)] = 2
new_course_data['High Performing Course'][new_course_data['sum_bookings'] < new_course_data['sum_bookings'].quantile(.25)] = 1
# Out:
# C:\Users\ochang\AppData\Local\Continuum\Anaconda2\lib\site-packages\ipykernel\__main__.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\ochang\AppData\Local\Continuum\Anaconda2\lib\site-packages\ipykernel\__main__.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\ochang\AppData\Local\Continuum\Anaconda2\lib\site-packages\ipykernel\__main__.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\ochang\AppData\Local\Continuum\Anaconda2\lib\site-packages\ipykernel\__main__.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
# Create multiclass based on quantiles

new_course_data['High Performing Course'] = 0

new_course_data['High Performing Course'][new_course_data['sum_bookings'] >= new_course_data['sum_bookings'].quantile(.66)] = 2
new_course_data['High Performing Course'][new_course_data['sum_bookings'] < new_course_data['sum_bookings'].quantile(.66)] = 1
new_course_data['High Performing Course'][new_course_data['sum_bookings'] < new_course_data['sum_bookings'].quantile(.33)] = 0
# Out:
# C:\Users\ochang\AppData\Local\Continuum\Anaconda2\lib\site-packages\ipykernel\__main__.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\ochang\AppData\Local\Continuum\Anaconda2\lib\site-packages\ipykernel\__main__.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\ochang\AppData\Local\Continuum\Anaconda2\lib\site-packages\ipykernel\__main__.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
new_course_data
# Out:
#                                              course_id  LiberalArts  STEM  \
# 0                    course-v1:ANUx+ANU-ASTRO1x+2T2016            0     1
# 1                    course-v1:ANUx+ANU-ASTRO2x+2T2016            0     1
# 2                    course-v1:ANUx+ANU-ASTRO3x+1T2016            0     1
# 3                    course-v1:ANUx+ANU-ASTRO4x+2T2016            0     1
# 4                 course-v1:ANUx+ANU-ActuarialX+1T2016            0     1
# 5                         course-v1:ANUx+EBM01x+1T2017            0     1
# 6                         course-v1:ANUx+EBM02x+2T2017            0     1
# 7                        course-v1:ASUx+GBL500x+3T2016            1     0
# 8                       course-v1:ASUx+GFADemox+1T2016            1     0
# 9                        course-v1:ASUx+MAT117x+1T2016            0     1
# 10                       course-v1:ASUx+MAT170x+2T2017            0     1
# 11                       course-v1:ASUx+TGM505x+2T2017            0     0
# 12                       course-v1:ASUx+TGM540x+2T2017            0     0
# 13               course-v1:AdelaideX+AddictionX+3T2016            1     1
# 14                 course-v1:AdelaideX+Code101x+1T2017            0     1
# 15                course-v1:AdelaideX+Cyber101x+1T2016            1     1
# 16                 course-v1:AdelaideX+Lang101x+3T2016            1     0
# 17              course-v1:AdelaideX+Project101x+1T2017            0     1
# 18                 course-v1:AdelaideX+Wine101x+2T2016            1     1
# 19     course-v1:AmnestyInternationalX+Rights2x+3T2016            1     0
# 20   course-v1:AmnestyInternationalX+Rights2xES+3T2016            1     0
# 21   course-v1:AmnestyInternationalX+Rights2xFR+3T2016            1     0
# 22                           course-v1:BAx+BAx4+2T2017            1     0
# 23                    course-v1:BUx+ComplianceX+4T2015            1     0
# 24                  course-v1:BUx+GlobalHealthX+1T2017            1     1
# 25                     course-v1:BUx+Math226.1x+2T2017            0     1
# 26                course-v1:BabsonX+BPET.ACCx+1T2017_2            0     0
# 27                course-v1:BabsonX+BPET.ETAx+1T2017_2            0     0
# 28                  course-v1:BabsonX+BPET.FINx+2T2017            0     0
# 29                 course-v1:BabsonX+BPET.STATx+2T2017            0     1
# ..                                                 ...          ...   ...
# 563      course-v1:University_of_TorontoX+HPT3x+2T2016            1     0
# 564    course-v1:University_of_TorontoX+INQ101x+3T2016            1     0
# 565                         course-v1:VJx+VJx_2+3T2016            1     0
# 566                       course-v1:W3Cx+CSS.0x+1T2017            0     1
# 567                     course-v1:W3Cx+HTML5.0x+1T2017            0     1
# 568                     course-v1:W3Cx+HTML5.1x+1T2017            0     1
# 569                        course-v1:W3Cx+JS.0x+1T2017            0     1
# 570                course-v1:WageningenX+AB101x+1T2017            0     1
# 571                 course-v1:WageningenX+BB01x+1T2017            0     1
# 572                 course-v1:WageningenX+BB02x+1T2017            0     1
# 573                 course-v1:WageningenX+BB03x+2T2017            0     1
# 574                 course-v1:WageningenX+FFESx+1T2017            1     1
# 575                course-v1:WageningenX+FSSFAx+2T2017            1     0
# 576                 course-v1:WageningenX+GFFCx+2T2016            0     1
# 577              course-v1:WageningenX+NUTR101x+2T2017            1     1
# 578              course-v1:WageningenX+NUTR102x+2T2017            1     1
# 579               course-v1:WageningenX+NUTR103+2T2017            1     1
# 580                 course-v1:WageningenX+Soilx+3T2016            0     1
# 581                   course-v1:WasedaX+JPC111x+1T2017            1     0
# 582       course-v1:Wharton+CustomerCentricityx+2T2017            0     0
# 583      course-v1:Wharton+DigitalMarketing1.1x+2T2017            0     0
# 584    course-v1:Wharton+MarketingAnalytics101x+2T2017            0     1
# 585          course-v1:Wharton+SellingIdeas101x+2T2017            0     0
# 586                 course-v1:Wharton+StrategyX+2T2017            0     0
# 587                    course-v1:WitsX+RBME101x+1T2017            0     0
# 588                      course-v1:edX+BlendedX+3T2016            1     0
# 589                       course-v1:edX+DemoX.1+2T2017            1     1
# 590                       course-v1:edX+StudioX+3T2016            1     0
# 591                        course-v1:edX+VideoX+3T2016            1     0
# 592                        course-v1:edX+edX101+3T2016            1     0
#
#      Business  cnt_subjects  is_WL    level_type       pacing_type  \
# 0           0             3      0  Intermediate        self_paced
# 1           0             2      0  Intermediate        self_paced
# 2           0             2      0  Intermediate        self_paced
# 3           0             2      0  Intermediate        self_paced
# 4           1             3      0  Introductory        self_paced
# 5           1             2      0  Intermediate        self_paced
# 6           1             2      0  Intermediate        self_paced
# 7           0             1      0  Introductory        self_paced
# 8           0             1      0  Introductory        self_paced
# 9           0             1      0  Introductory        self_paced
# 10          0             1      0  Intermediate        self_paced
# 11          1             1      0  Intermediate  instructor_paced
# 12          1             1      0  Intermediate  instructor_paced
# 13          0             3      0  Introductory        self_paced
# 14          0             1      0  Introductory        self_paced
# 15          0             3      0  Introductory        self_paced
# 16          1             3      0  Introductory        self_paced
# 17          1             3      0  Introductory        self_paced
# 18          0             3      0  Introductory        self_paced
# 19          0             3      0  Introductory        self_paced
# 20          0             3      0  Introductory        self_paced
# 21          0             3      0  Introductory        self_paced
# 22          0             2      0  Introductory  instructor_paced
# 23          0             1      0      Advanced        self_paced
# 24          0             3      0  Introductory        self_paced
# 25          0             1      0  Intermediate  instructor_paced
# 26          1             1      0  Introductory  instructor_paced
# 27          1             1      0  Introductory        self_paced
# 28          1             2      0  Introductory  instructor_paced
# 29          1             2      0  Introductory        self_paced
# ..        ...           ...    ...           ...               ...
# 563         0             1      0  Intermediate        self_paced
# 564         0             2      0  Intermediate  instructor_paced
# 565         0             1      0  Introductory        self_paced
# 566         0             1      0  Introductory        self_paced
# 567         0             1      0  Introductory        self_paced
# 568         0             1      0  Intermediate        self_paced
# 569         0             1      0  Introductory  instructor_paced
# 570         0             2      0  Introductory  instructor_paced
# 571         0             3      0  Intermediate        self_paced
# 572         1             4      0  Intermediate        self_paced
# 573         0             3      0      Advanced        self_paced
# 574         0             3      0  Introductory        self_paced
# 575         0             2      0  Introductory        self_paced
# 576         0             2      0  Intermediate        self_paced
# 577         0             3      0  Introductory        self_paced
# 578         0             3      0  Intermediate        self_paced
# 579         0             3      0  Introductory        self_paced
# 580         0             1      0  Introductory        self_paced
# 581         1             3      0  Introductory  instructor_paced
# 582         1             1      0  Intermediate        self_paced
# 583         1             1      0  Intermediate        self_paced
# 584         1             2      0  Intermediate        self_paced
# 585         1             1      0  Intermediate        self_paced
# 586         1             1      0  Intermediate        self_paced
# 587         1             1      0  Intermediate  instructor_paced
# 588         0             1      0  Intermediate        self_paced
# 589         1            24      0  Introductory        self_paced
# 590         0             1      0  Introductory        self_paced
# 591         0             1      0  Introductory        self_paced
# 592         0             1      0  Introductory        self_paced
#
#              course_partner  trust_bar_tier_1           ...            \
# 0                      ANUx                 0           ...
# 1                      ANUx                 0           ...
# 2                      ANUx                 0           ...
# 3                      ANUx                 0           ...
# 4                      ANUx                 0           ...
# 5                      ANUx                 0           ...
# 6                      ANUx                 0           ...
# 7                      ASUx                 0           ...
# 8                      ASUx                 0           ...
# 9                      ASUx                 0           ...
# 10                     ASUx                 0           ...
# 11                     ASUx                 0           ...
# 12                     ASUx                 0           ...
# 13                AdelaideX                 0           ...
# 14                AdelaideX                 0           ...
# 15                AdelaideX                 0           ...
# 16                AdelaideX                 0           ...
# 17                AdelaideX                 0           ...
# 18                AdelaideX                 0           ...
# 19    AmnestyInternationalX                 0           ...
# 20    AmnestyInternationalX                 0           ...
# 21    AmnestyInternationalX                 0           ...
# 22                      BAx                 0           ...
# 23                      BUx                 0           ...
# 24                      BUx                 0           ...
# 25                      BUx                 0           ...
# 26                  BabsonX                 0           ...
# 27                  BabsonX                 0           ...
# 28                  BabsonX                 0           ...
# 29                  BabsonX                 0           ...
# ..                      ...               ...           ...
# 563  University_of_TorontoX                 0           ...
# 564  University_of_TorontoX                 0           ...
# 565                     VJx                 0           ...
# 566                    W3Cx                 0           ...
# 567                    W3Cx                 0           ...
# 568                    W3Cx                 0           ...
# 569                    W3Cx                 0           ...
# 570             WageningenX                 0           ...
# 571             WageningenX                 0           ...
# 572             WageningenX                 0           ...
# 573             WageningenX                 0           ...
# 574             WageningenX                 0           ...
# 575             WageningenX                 0           ...
# 576             WageningenX                 0           ...
# 577             WageningenX                 0           ...
# 578             WageningenX                 0           ...
# 579             WageningenX                 0           ...
# 580             WageningenX                 0           ...
# 581                 WasedaX                 0           ...
# 582                 Wharton                 0           ...
# 583                 Wharton                 0           ...
# 584                 Wharton                 0           ...
# 585                 Wharton                 0           ...
# 586                 Wharton                 0           ...
# 587                   WitsX                 0           ...
# 588                     edX                 0           ...
# 589                     edX                 0           ...
# 590                     edX                 0           ...
# 591                     edX                 0           ...
# 592                     edX                 0           ...
#
#                       vtr  bookings_rank  bookings_per_course_rank  \
# 0    0.016737123630402899             22                        35
# 1    0.011424840868287906             22                        35
# 2    0.009901721717283677             22                        35
# 3    0.011256841887844676             22                        35
# 4    0.013601111239726820             22                        35
# 5    0.012616201859229748             22                        35
# 6    0.004131012097964001             22                        35
# 7    0.012845849802371542             11                        32
# 8                   0E-18             11                        32
# 9    0.022742015492044110             11                        32
# 10   0.011120263591433278             11                        32
# 11   0.009420631182289213             11                        32
# 12   0.013559322033898305             11                        32
# 13   0.040847201210287443             17                        19
# 14                  0E-18             17                        19
# 15   0.025943196269605765             17                        19
# 16   0.012317518248175182             17                        19
# 17   0.018924079065588500             17                        19
# 18   0.017281806339557099             17                        19
# 19   0.028266017772177200             38                        14
# 20   0.020688358096671055             38                        14
# 21   0.018425219519216928             38                        14
# 22   0.006134969325153374            130                       122
# 23                  0E-18             25                        79
# 24   0.016666666666666667             25                        79
# 25   0.016594516594516595             25                        79
# 26   0.010876519513755598             84                        87
# 27   0.009767598518019535             84                        87
# 28   0.008314436885865457             84                        87
# 29   0.006969696969696970             84                        87
# ..                    ...            ...                       ...
# 563  0.036303630363036304             55                        62
# 564  0.009046624913013222             55                        62
# 565  0.015713591446622388             99                        66
# 566  0.004159733777038270             20                        16
# 567  0.004190826109420747             20                        16
# 568  0.002416188462700091             20                        16
# 569  0.003170227429359063             20                        16
# 570  0.013172043010752688             30                        53
# 571  0.006036931818181818             30                        53
# 572  0.001363326516700750             30                        53
# 573  0.000709219858156028             30                        53
# 574  0.014889815366289458             30                        53
# 575  0.014261744966442953             30                        53
# 576  0.013929088277858177             30                        53
# 577  0.011589403973509934             30                        53
# 578  0.009015256588072122             30                        53
# 579  0.008645533141210375             30                        53
# 580  0.015122873345935728             30                        53
# 581  0.003807545863620630            122                       119
# 582                 0E-18             12                         7
# 583                 0E-18             12                         7
# 584                 0E-18             12                         7
# 585                 0E-18             12                         7
# 586                 0E-18             12                         7
# 587  0.028711749149981111             93                        72
# 588  0.028994447871684146            106                       140
# 589                 0E-18            106                       140
# 590  0.012176084920387137            106                       140
# 591  0.010425354462051710            106                       140
# 592  0.021747143383708072            106                       140
#
#      sum_bookings  instructor_paced  self_paced  Advanced  Intermediate  \
# 0    18535.000000                 0           1         0             1
# 1     9980.000000                 0           1         0             1
# 2     6173.000000                 0           1         0             1
# 3     5093.000000                 0           1         0             1
# 4    10914.000000                 0           1         0             0
# 5    12717.000000                 0           1         0             1
# 6     1810.000000                 0           1         0             1
# 7     1892.000000                 0           1         0             0
# 8       45.000000                 0           1         0             0
# 9    68180.000000                 0           1         0             0
# 10    2739.000000                 0           1         0             1
# 11    8436.000000                 1           0         0             1
# 12    7256.000000                 1           0         0             1
# 13    6523.000000                 0           1         0             0
# 14    7753.456446                 0           1         0             0
# 15   28354.000000                 0           1         0             0
# 16    1253.000000                 0           1         0             0
# 17   16171.000000                 0           1         0             0
# 18    9923.000000                 0           1         0             0
# 19   61176.000000                 0           1         0             0
# 20   10626.000000                 0           1         0             0
# 21    6088.000000                 0           1         0             0
# 22      25.000000                 1           0         0             0
# 23   29700.000000                 0           1         1             0
# 24    1508.000000                 0           1         0             0
# 25     986.000000                 1           0         0             1
# 26     792.000000                 1           0         0             0
# 27    1261.000000                 0           1         0             0
# 28    1537.000000                 1           0         0             0
# 29     939.000000                 0           1         0             0
# ..            ...               ...         ...       ...           ...
# 563   2048.000000                 0           1         0             1
# 564    605.000000                 1           0         0             1
# 565   6499.000000                 0           1         0             0
# 566    924.000000                 0           1         0             0
# 567   6768.000000                 0           1         0             0
# 568   1460.000000                 0           1         0             1
# 569   2121.000000                 1           0         0             0
# 570   2181.000000                 1           0         0             0
# 571   6080.000000                 0           1         0             1
# 572    617.000000                 0           1         0             1
# 573    249.000000                 0           1         1             0
# 574   3127.000000                 0           1         0             0
# 575    657.000000                 0           1         0             0
# 576   3403.000000                 0           1         0             1
# 577    998.000000                 0           1         0             0
# 578    590.000000                 0           1         0             1
# 579    355.000000                 0           1         0             0
# 580   2970.000000                 0           1         0             0
# 581    488.000000                 1           0         0             0
# 582  23810.000000                 0           1         0             1
# 583  76869.000000                 0           1         0             1
# 584  19130.000000                 0           1         0             1
# 585  13865.000000                 0           1         0             1
# 586  31590.000000                 0           1         0             1
# 587   3509.000000                 1           0         0             1
# 588   2333.000000                 0           1         0             1
# 589    106.000000                 0           1         0             0
# 590    925.000000                 0           1         0             0
# 591    630.000000                 0           1         0             0
# 592   1436.000000                 0           1         0             0
#
#      Introductory  High Performing Course
# 0               0                       2
# 1               0                       2
# 2               0                       2
# 3               0                       2
# 4               1                       2
# 5               0                       2
# 6               0                       1
# 7               1                       1
# 8               1                       0
# 9               1                       2
# 10              0                       1
# 11              0                       2
# 12              0                       2
# 13              1                       2
# 14              1                       2
# 15              1                       2
# 16              1                       1
# 17              1                       2
# 18              1                       2
# 19              1                       2
# 20              1                       2
# 21              1                       2
# 22              1                       0
# 23              0                       2
# 24              1                       1
# 25              0                       1
# 26              1                       0
# 27              1                       1
# 28              1                       1
# 29              1                       1
# ..            ...                     ...
# 563             0                       1
# 564             0                       0
# 565             1                       2
# 566             1                       1
# 567             1                       2
# 568             0                       1
# 569             1                       1
# 570             1                       1
# 571             0                       2
# 572             0                       0
# 573             0                       0
# 574             1                       1
# 575             1                       0
# 576             0                       1
# 577             1                       1
# 578             0                       0
# 579             1                       0
# 580             1                       1
# 581             1                       0
# 582             0                       2
# 583             0                       2
# 584             0                       2
# 585             0                       2
# 586             0                       2
# 587             0                       1
# 588             0                       1
# 589             1                       0
# 590             1                       1
# 591             1                       0
# 592             1                       1
#
# [593 rows x 53 columns]

# %%
X_new = new_course_data[feature_cols]

new_course_data['Predictions'] = etc.predict(X_new)

# %%
print metrics.confusion_matrix(new_course_data['High Performing Course'], new_course_data['Predictions'], labels=[0, 1, 2])
# Out:
# [[193   3   0]
#  [175  20   0]
#  [189  13   0]]

# %%
print metrics.classification_report(new_course_data['High Performing Course'], new_course_data['Predictions'])
# Out:
#              precision    recall  f1-score   support
#
#           0       0.35      0.98      0.51       196
#           1       0.56      0.10      0.17       195
#           2       0.00      0.00      0.00       202
#
# avg / total       0.30      0.36      0.23       593

# %%
display_cols = ['course_id', 'sum_bookings', 'Predictions', 'High Performing Course']

new_course_data[display_cols]
# Out:
#                                              course_id  sum_bookings  \
# 0                    course-v1:ANUx+ANU-ASTRO1x+2T2016  18535.000000
# 1                    course-v1:ANUx+ANU-ASTRO2x+2T2016   9980.000000
# 2                    course-v1:ANUx+ANU-ASTRO3x+1T2016   6173.000000
# 3                    course-v1:ANUx+ANU-ASTRO4x+2T2016   5093.000000
# 4                 course-v1:ANUx+ANU-ActuarialX+1T2016  10914.000000
# 5                         course-v1:ANUx+EBM01x+1T2017  12717.000000
# 6                         course-v1:ANUx+EBM02x+2T2017   1810.000000
# 7                        course-v1:ASUx+GBL500x+3T2016   1892.000000
# 8                       course-v1:ASUx+GFADemox+1T2016     45.000000
# 9                        course-v1:ASUx+MAT117x+1T2016  68180.000000
# 10                       course-v1:ASUx+MAT170x+2T2017   2739.000000
# 11                       course-v1:ASUx+TGM505x+2T2017   8436.000000
# 12                       course-v1:ASUx+TGM540x+2T2017   7256.000000
# 13               course-v1:AdelaideX+AddictionX+3T2016   6523.000000
# 14                 course-v1:AdelaideX+Code101x+1T2017   7753.456446
# 15                course-v1:AdelaideX+Cyber101x+1T2016  28354.000000
# 16                 course-v1:AdelaideX+Lang101x+3T2016   1253.000000
# 17              course-v1:AdelaideX+Project101x+1T2017  16171.000000
# 18                 course-v1:AdelaideX+Wine101x+2T2016   9923.000000
# 19     course-v1:AmnestyInternationalX+Rights2x+3T2016  61176.000000
# 20   course-v1:AmnestyInternationalX+Rights2xES+3T2016  10626.000000
# 21   course-v1:AmnestyInternationalX+Rights2xFR+3T2016   6088.000000
# 22                           course-v1:BAx+BAx4+2T2017     25.000000
# 23                    course-v1:BUx+ComplianceX+4T2015  29700.000000
# 24                  course-v1:BUx+GlobalHealthX+1T2017   1508.000000
# 25                     course-v1:BUx+Math226.1x+2T2017    986.000000
# 26                course-v1:BabsonX+BPET.ACCx+1T2017_2    792.000000
# 27                course-v1:BabsonX+BPET.ETAx+1T2017_2   1261.000000
# 28                  course-v1:BabsonX+BPET.FINx+2T2017   1537.000000
# 29                 course-v1:BabsonX+BPET.STATx+2T2017    939.000000
# ..                                                 ...           ...
# 563      course-v1:University_of_TorontoX+HPT3x+2T2016   2048.000000
# 564    course-v1:University_of_TorontoX+INQ101x+3T2016    605.000000
# 565                         course-v1:VJx+VJx_2+3T2016   6499.000000
# 566                       course-v1:W3Cx+CSS.0x+1T2017    924.000000
# 567                     course-v1:W3Cx+HTML5.0x+1T2017   6768.000000
# 568                     course-v1:W3Cx+HTML5.1x+1T2017   1460.000000
# 569                        course-v1:W3Cx+JS.0x+1T2017   2121.000000
# 570                course-v1:WageningenX+AB101x+1T2017   2181.000000
# 571                 course-v1:WageningenX+BB01x+1T2017   6080.000000
# 572                 course-v1:WageningenX+BB02x+1T2017    617.000000
# 573                 course-v1:WageningenX+BB03x+2T2017    249.000000
# 574                 course-v1:WageningenX+FFESx+1T2017   3127.000000
# 575                course-v1:WageningenX+FSSFAx+2T2017    657.000000
# 576                 course-v1:WageningenX+GFFCx+2T2016   3403.000000
# 577              course-v1:WageningenX+NUTR101x+2T2017    998.000000
# 578              course-v1:WageningenX+NUTR102x+2T2017    590.000000
# 579               course-v1:WageningenX+NUTR103+2T2017    355.000000
# 580                 course-v1:WageningenX+Soilx+3T2016   2970.000000
# 581                   course-v1:WasedaX+JPC111x+1T2017    488.000000
# 582       course-v1:Wharton+CustomerCentricityx+2T2017  23810.000000
# 583      course-v1:Wharton+DigitalMarketing1.1x+2T2017  76869.000000
# 584    course-v1:Wharton+MarketingAnalytics101x+2T2017  19130.000000
# 585          course-v1:Wharton+SellingIdeas101x+2T2017  13865.000000
# 586                 course-v1:Wharton+StrategyX+2T2017  31590.000000
# 587                    course-v1:WitsX+RBME101x+1T2017   3509.000000
# 588                      course-v1:edX+BlendedX+3T2016   2333.000000
# 589                       course-v1:edX+DemoX.1+2T2017    106.000000
# 590                       course-v1:edX+StudioX+3T2016    925.000000
# 591                        course-v1:edX+VideoX+3T2016    630.000000
# 592                        course-v1:edX+edX101+3T2016   1436.000000
#
#      Predictions  High Performing Course
# 0              0                       2
# 1              0                       2
# 2              0                       2
# 3              0                       2
# 4              0                       2
# 5              0                       2
# 6              0                       1
# 7              0                       1
# 8              0                       0
# 9              0                       2
# 10             0                       1
# 11             0                       2
# 12             0                       2
# 13             0                       2
# 14             0                       2
# 15             0                       2
# 16             0                       1
# 17             0                       2
# 18             0                       2
# 19             0                       2
# 20             0                       2
# 21             0                       2
# 22             0                       0
# 23             0                       2
# 24             0                       1
# 25             0                       1
# 26             0                       0
# 27             0                       1
# 28             0                       1
# 29             0                       1
# ..           ...                     ...
# 563            0                       1
# 564            0                       0
# 565            0                       2
# 566            0                       1
# 567            0                       2
# 568            0                       1
# 569            0                       1
# 570            0                       1
# 571            0                       2
# 572            0                       0
# 573            0                       0
# 574            0                       1
# 575            0                       0
# 576            0                       1
# 577            0                       1
# 578            0                       0
# 579            0                       0
# 580            0                       1
# 581            0                       0
# 582            0                       2
# 583            0                       2
# 584            0                       2
# 585            0                       2
# 586            0                       2
# 587            0                       1
# 588            0                       1
# 589            0                       0
# 590            0                       1
# 591            0                       0
# 592            0                       1
#
# [593 rows x 4 columns]

# %%
course_metadata_query = """
SELECT
    course_id,
    course_partner,
    course_start_date,
    course_end_date,
    course_verification_end_date,
    course_verification_end_date - CURRENT_DATE() AS days_til_verification_date
FROM
    business_intelligence.course_master
"""

# Execute the Query from above
cur.execute(course_metadata_query)

# Dump the query results into a Pandas DataFrame
course_metadata = pd.DataFrame(cur.fetchall())

# %%
output_data = pd.merge(new_course_data[display_cols], course_metadata, how='left', on='course_id')

# %%
# Print out results to csv
output_path = '/Users/ochang/Downloads/high_performing_courses.csv'
output_data.to_csv(output_path)
